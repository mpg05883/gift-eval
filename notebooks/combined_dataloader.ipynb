# %% [markdown]
# # Combined entries Loader Strategies

# %% [markdown]
# This notebook contains several strategies for combining multiple datasets into a single data loader using GluonTS. The goal is for each batch of the data loader to **contain a balanced mix of samples each datasets**.

# %% [markdown]
# ## Initialization

# %% [markdown]
# Define a function to generate dummy datasets.

# %%
from gluonts.dataset.common import ListDataset
import pandas as pd
import numpy as np


def generate_dummy_dataset(
    start_date="01-01-2019",
    freq="1h",
    num_entries=10,
    num_timesteps=100,
    source=None,
):
    """
    Utility function to generate a dataset of random time series entries.

    Args:
        start_date (str or pd.Timestamp): The start timestamp for each entry
            (e.g., "2023-01-01").
        freq (str): The frequency of the time series (e.g., "1H", "1D").
        num_entries (int): The number of time series to generate.
        num_timesteps (int): The number of time steps in each time series.
        source (str): A label identifying which dataset the time series
                belongs to.

    Returns:
        ListDataset[Dict]: A list of dictionaries, where each dictionary is a
            time series entry with "start", "target", and "source" keys.
    """
    start = pd.Period(start_date, freq=freq)
    dataset = np.random.normal(size=(num_entries, num_timesteps))

    return ListDataset(
        [
            {
                "start": start,
                "target": target,
                "source": source,  # Custom field to track dataset
                "series_number": index,
            }
            for index, target in enumerate(dataset)
        ],
        freq=freq,
    )

# %% [markdown]
# Initialize some dummy datasets for us to use.

# %%
dataset_one = generate_dummy_dataset(
    source="Dataset 1",
    num_entries=10,
    num_timesteps=100,
)
dataset_two = generate_dummy_dataset(
    source="Dataset 2",
    num_entries=50,
    num_timesteps=500,
)
dataset_three = generate_dummy_dataset(
    source="Dataset 3",
    num_entries=100,
    num_timesteps=1000,
)
dataset_four = generate_dummy_dataset(
    source="Dataset 4",
    num_entries=1000,
    num_timesteps=1000,
)


context_length = 48
prediction_length = 24

# %% [markdown]
# Take a look at the first entry of each dataset.

# %%
datasets = [dataset_one, dataset_two, dataset_three, dataset_four]

for dataset in datasets:
    first_entry = next(iter(dataset))
    print(f"start: {first_entry['start']}")
    print(f"target: {first_entry['target'][:10]}")
    print(f"source: {first_entry['source']}")
    print(f"series number: {first_entry['series_number']}")
    print("-" * 80)
# Out:
# start: 2019-01-01 00:00
# target: [-0.6787465  -0.95481426  0.80087197  0.60148644  1.9362926   0.6924021
#  -0.63677317 -0.38945454  1.1554981  -2.0923688 ]
# source: Dataset 1
# series number: 0
# --------------------------------------------------------------------------------
# start: 2019-01-01 00:00
# target: [ 0.33069488  0.2391058   1.4121292   1.9540036  -0.24719605  0.2795431
#   0.82791764 -1.6132694  -0.91395915 -1.8362839 ]
# source: Dataset 2
# series number: 0
# --------------------------------------------------------------------------------
# start: 2019-01-01 00:00
# target: [ 0.02935562 -2.1665876  -0.4610103  -0.15737787 -1.3025767  -0.7422203
#   1.6018269   0.26374477 -0.93608266 -0.3171792 ]
# source: Dataset 3
# series number: 0
# --------------------------------------------------------------------------------
# start: 2019-01-01 00:00
# target: [ 2.0260003   0.8996754  -0.062847   -1.1292576   1.2507395   0.89989054
#   0.9305872  -0.89675844  1.0092256   1.8340392 ]
# source: Dataset 4
# series number: 0
# --------------------------------------------------------------------------------

# %% [markdown]
# ## Strategies

# %% [markdown]
# Here are some stratigies I came up with for combining multiple datasets into a single data loader.

# %% [markdown]
# ### Strategy 1

# %% [markdown]
# Store all of the datasets in a `DatasetCollection` object with `interleave` set to True.

# %%
from gluonts.dataset import DatasetCollection
from gluonts.itertools import Cyclic

dataset_collection = DatasetCollection(
    datasets=[Cyclic(dataset) for dataset in datasets],
    interleave=True,
)

# %% [markdown]
# Define transformations for the data loader.

# %%
from gluonts.dataset.field_names import FieldName
from gluonts.transform import (
    AddObservedValuesIndicator,
    InstanceSplitter,
    ExpectedNumInstanceSampler,
)

mask_unobserved = AddObservedValuesIndicator(
    target_field=FieldName.TARGET,
    output_field=FieldName.OBSERVED_VALUES,
)

instance_sampler = ExpectedNumInstanceSampler(
    num_instances=1,
    min_future=prediction_length,
)

time_series_fields = [FieldName.OBSERVED_VALUES]

splitter = InstanceSplitter(
    target_field=FieldName.TARGET,
    is_pad_field=FieldName.IS_PAD,
    start_field=FieldName.START,
    forecast_start_field=FieldName.FORECAST_START,
    instance_sampler=instance_sampler,
    past_length=context_length,
    future_length=prediction_length,
    time_series_fields=time_series_fields,
)

# %% [markdown]
# Initialize a `TrainDataLoader` with `shuffle_buffer_length` set to a non-zero integer.

# %%
from gluonts.dataset.loader import TrainDataLoader
from gluonts.torch.batchify import batchify

batch_size = 32
num_batches_per_epoch = 1000

data_loader = TrainDataLoader(
    dataset=dataset_collection,
    batch_size=batch_size,
    stack_fn=batchify,
    transform=mask_unobserved + splitter,
    num_batches_per_epoch=num_batches_per_epoch,
    # shuffle_buffer_length=1024,
)

# %% [markdown]
# Count how many samples belong to each dataset in each batch.
# - Each batch is a dict of key-value pairs:
#   - Each key is a different feature e.g. "start" or "past_target"
#   - Each value is a list of `batch_size` elements

# %%
from collections import Counter

counter = Counter()

for i, batch in enumerate(data_loader):
    print(f"Batch {i + 1}")

    series_numbers = batch["series_number"]
    sources = batch["source"]

    # See which time series where used for this batch
    print(
        {
            series_number: source
            for series_number, source in zip(series_numbers, sources)
        }
    )

    # Update counter with number of entries from each source in the batch
    counter.update(sources)
    print(f"Running counter: {dict(sorted(counter.items()))}")

    # Count the total number of entries in the batch
    total = sum(counter.values())

    # Convert each count to percentages
    percentages = {k: f"{str((v / total) * 100)}%" for k, v in counter.items()}
    print(f"Running percentages: {dict(sorted(percentages.items()))}")
    print("-" * 80)
# Out:
# Batch 1
# {0: 'Dataset 4', 1: 'Dataset 4', 2: 'Dataset 4', 3: 'Dataset 3', 4: 'Dataset 4', 5: 'Dataset 4', 6: 'Dataset 4'}
# Running counter: {'Dataset 1': 1, 'Dataset 2': 7, 'Dataset 3': 11, 'Dataset 4': 13}
# Running percentages: {'Dataset 1': '3.125%', 'Dataset 2': '21.875%', 'Dataset 3': '34.375%', 'Dataset 4': '40.625%'}
# --------------------------------------------------------------------------------
# Batch 2
# {7: 'Dataset 4', 8: 'Dataset 4', 9: 'Dataset 3', 10: 'Dataset 4', 1: 'Dataset 1', 11: 'Dataset 4', 12: 'Dataset 4', 13: 'Dataset 4', 14: 'Dataset 4', 15: 'Dataset 2'}
# Running counter: {'Dataset 1': 2, 'Dataset 2': 13, 'Dataset 3': 24, 'Dataset 4': 25}
# Running percentages: {'Dataset 1': '3.125%', 'Dataset 2': '20.3125%', 'Dataset 3': '37.5%', 'Dataset 4': '39.0625%'}
# --------------------------------------------------------------------------------
# Batch 3
# {15: 'Dataset 4', 16: 'Dataset 4', 17: 'Dataset 4', 19: 'Dataset 3', 20: 'Dataset 4', 21: 'Dataset 3'}
# Running counter: {'Dataset 1': 2, 'Dataset 2': 22, 'Dataset 3': 37, 'Dataset 4': 35}
# Running percentages: {'Dataset 1': '2.083333333333333%', 'Dataset 2': '22.916666666666664%', 'Dataset 3': '38.54166666666667%', 'Dataset 4': '36.45833333333333%'}
# --------------------------------------------------------------------------------
# Batch 4
# {21: 'Dataset 4', 2: 'Dataset 1', 22: 'Dataset 3', 23: 'Dataset 4', 24: 'Dataset 4', 25: 'Dataset 4', 6: 'Dataset 1', 26: 'Dataset 4', 27: 'Dataset 3', 28: 'Dataset 4', 29: 'Dataset 2'}
# Running counter: {'Dataset 1': 4, 'Dataset 2': 31, 'Dataset 3': 49, 'Dataset 4': 44}
# Running percentages: {'Dataset 1': '3.125%', 'Dataset 2': '24.21875%', 'Dataset 3': '38.28125%', 'Dataset 4': '34.375%'}
# --------------------------------------------------------------------------------
# Batch 5
# {29: 'Dataset 4', 30: 'Dataset 4', 31: 'Dataset 4', 32: 'Dataset 3', 33: 'Dataset 4', 34: 'Dataset 4', 35: 'Dataset 3', 6: 'Dataset 1', 36: 'Dataset 4'}
# Running counter: {'Dataset 1': 5, 'Dataset 2': 39, 'Dataset 3': 62, 'Dataset 4': 54}
# Running percentages: {'Dataset 1': '3.125%', 'Dataset 2': '24.375%', 'Dataset 3': '38.75%', 'Dataset 4': '33.75%'}
# --------------------------------------------------------------------------------
# Batch 6
# {37: 'Dataset 4', 38: 'Dataset 4', 39: 'Dataset 3', 40: 'Dataset 4', 41: 'Dataset 4', 42: 'Dataset 4', 43: 'Dataset 2', 44: 'Dataset 4'}
# Running counter: {'Dataset 1': 5, 'Dataset 2': 48, 'Dataset 3': 71, 'Dataset 4': 68}
# Running percentages: {'Dataset 1': '2.604166666666667%', 'Dataset 2': '25.0%', 'Dataset 3': '36.97916666666667%', 'Dataset 4': '35.41666666666667%'}
# --------------------------------------------------------------------------------
# Batch 7
# {45: 'Dataset 4', 46: 'Dataset 4', 48: 'Dataset 4', 49: 'Dataset 4', 50: 'Dataset 3', 51: 'Dataset 4'}
# Running counter: {'Dataset 1': 5, 'Dataset 2': 53, 'Dataset 3': 86, 'Dataset 4': 80}
# Running percentages: {'Dataset 1': '2.232142857142857%', 'Dataset 2': '23.660714285714285%', 'Dataset 3': '38.392857142857146%', 'Dataset 4': '35.714285714285715%'}
# --------------------------------------------------------------------------------
# Batch 8
# {51: 'Dataset 4', 52: 'Dataset 4', 53: 'Dataset 4', 4: 'Dataset 2', 54: 'Dataset 4', 5: 'Dataset 2', 55: 'Dataset 4', 6: 'Dataset 2', 7: 'Dataset 2', 57: 'Dataset 4', 8: 'Dataset 2', 58: 'Dataset 4', 9: 'Dataset 2', 59: 'Dataset 4'}
# Running counter: {'Dataset 1': 5, 'Dataset 2': 62, 'Dataset 3': 94, 'Dataset 4': 95}
# Running percentages: {'Dataset 1': '1.953125%', 'Dataset 2': '24.21875%', 'Dataset 3': '36.71875%', 'Dataset 4': '37.109375%'}
# --------------------------------------------------------------------------------
# Batch 9
# {10: 'Dataset 2', 60: 'Dataset 3', 61: 'Dataset 4', 12: 'Dataset 2', 62: 'Dataset 3', 13: 'Dataset 2', 63: 'Dataset 4', 14: 'Dataset 2', 64: 'Dataset 4', 15: 'Dataset 2', 65: 'Dataset 4'}
# Running counter: {'Dataset 1': 5, 'Dataset 2': 71, 'Dataset 3': 109, 'Dataset 4': 103}
# Running percentages: {'Dataset 1': '1.7361111111111112%', 'Dataset 2': '24.65277777777778%', 'Dataset 3': '37.84722222222222%', 'Dataset 4': '35.76388888888889%'}
# --------------------------------------------------------------------------------
# Batch 10
# {66: 'Dataset 4', 17: 'Dataset 2', 67: 'Dataset 3', 18: 'Dataset 2', 68: 'Dataset 4', 69: 'Dataset 4', 20: 'Dataset 2', 70: 'Dataset 4', 71: 'Dataset 4', 72: 'Dataset 4', 23: 'Dataset 2', 73: 'Dataset 3'}
# Running counter: {'Dataset 1': 5, 'Dataset 2': 77, 'Dataset 3': 123, 'Dataset 4': 115}
# Running percentages: {'Dataset 1': '1.5625%', 'Dataset 2': '24.0625%', 'Dataset 3': '38.4375%', 'Dataset 4': '35.9375%'}
# --------------------------------------------------------------------------------
# Batch 11
# {73: 'Dataset 4', 74: 'Dataset 3', 75: 'Dataset 4', 26: 'Dataset 2', 76: 'Dataset 4', 27: 'Dataset 2', 77: 'Dataset 4', 28: 'Dataset 2', 78: 'Dataset 4', 29: 'Dataset 2', 79: 'Dataset 3', 80: 'Dataset 4', 31: 'Dataset 2', 81: 'Dataset 3'}
# Running counter: {'Dataset 1': 5, 'Dataset 2': 85, 'Dataset 3': 137, 'Dataset 4': 125}
# Running percentages: {'Dataset 1': '1.4204545454545454%', 'Dataset 2': '24.147727272727273%', 'Dataset 3': '38.92045454545455%', 'Dataset 4': '35.51136363636363%'}
# --------------------------------------------------------------------------------
# Batch 12
# {81: 'Dataset 4', 82: 'Dataset 3', 33: 'Dataset 2', 83: 'Dataset 4', 34: 'Dataset 2', 84: 'Dataset 4', 35: 'Dataset 2', 85: 'Dataset 3', 36: 'Dataset 2', 86: 'Dataset 3', 87: 'Dataset 4', 38: 'Dataset 2', 88: 'Dataset 4'}
# Running counter: {'Dataset 1': 5, 'Dataset 2': 92, 'Dataset 3': 149, 'Dataset 4': 138}
# Running percentages: {'Dataset 1': '1.3020833333333335%', 'Dataset 2': '23.958333333333336%', 'Dataset 3': '38.80208333333333%', 'Dataset 4': '35.9375%'}
# --------------------------------------------------------------------------------
# Batch 13
# {39: 'Dataset 2', 89: 'Dataset 4', 90: 'Dataset 4', 41: 'Dataset 2', 91: 'Dataset 4', 42: 'Dataset 2', 92: 'Dataset 4', 93: 'Dataset 4', 94: 'Dataset 4', 45: 'Dataset 2', 95: 'Dataset 4'}
# Running counter: {'Dataset 1': 5, 'Dataset 2': 100, 'Dataset 3': 162, 'Dataset 4': 149}
# Running percentages: {'Dataset 1': '1.201923076923077%', 'Dataset 2': '24.03846153846154%', 'Dataset 3': '38.94230769230769%', 'Dataset 4': '35.81730769230769%'}
# --------------------------------------------------------------------------------
# Batch 14
# {96: 'Dataset 4', 7: 'Dataset 1', 97: 'Dataset 4', 48: 'Dataset 2', 99: 'Dataset 4', 100: 'Dataset 4', 1: 'Dataset 3', 101: 'Dataset 4', 2: 'Dataset 3', 102: 'Dataset 4', 3: 'Dataset 3', 103: 'Dataset 4', 4: 'Dataset 3'}
# Running counter: {'Dataset 1': 7, 'Dataset 2': 104, 'Dataset 3': 174, 'Dataset 4': 163}
# Running percentages: {'Dataset 1': '1.5625%', 'Dataset 2': '23.214285714285715%', 'Dataset 3': '38.839285714285715%', 'Dataset 4': '36.38392857142857%'}
# --------------------------------------------------------------------------------
# Batch 15
# {4: 'Dataset 3', 104: 'Dataset 4', 5: 'Dataset 3', 105: 'Dataset 4', 6: 'Dataset 3', 106: 'Dataset 4', 7: 'Dataset 2', 107: 'Dataset 4', 8: 'Dataset 1', 108: 'Dataset 4', 9: 'Dataset 3', 109: 'Dataset 4', 10: 'Dataset 3'}
# Running counter: {'Dataset 1': 8, 'Dataset 2': 109, 'Dataset 3': 184, 'Dataset 4': 179}
# Running percentages: {'Dataset 1': '1.6666666666666667%', 'Dataset 2': '22.708333333333332%', 'Dataset 3': '38.333333333333336%', 'Dataset 4': '37.291666666666664%'}
# --------------------------------------------------------------------------------
# Batch 16
# {10: 'Dataset 3', 110: 'Dataset 4', 11: 'Dataset 3', 111: 'Dataset 4', 12: 'Dataset 2', 112: 'Dataset 4', 13: 'Dataset 3', 113: 'Dataset 4', 14: 'Dataset 3', 114: 'Dataset 4', 15: 'Dataset 3', 115: 'Dataset 4', 6: 'Dataset 1', 16: 'Dataset 2', 116: 'Dataset 4', 7: 'Dataset 1'}
# Running counter: {'Dataset 1': 10, 'Dataset 2': 121, 'Dataset 3': 193, 'Dataset 4': 188}
# Running percentages: {'Dataset 1': '1.953125%', 'Dataset 2': '23.6328125%', 'Dataset 3': '37.6953125%', 'Dataset 4': '36.71875%'}
# --------------------------------------------------------------------------------
# Batch 17
# {17: 'Dataset 3', 117: 'Dataset 4', 18: 'Dataset 3', 118: 'Dataset 4', 19: 'Dataset 3', 119: 'Dataset 4', 20: 'Dataset 3', 120: 'Dataset 4', 121: 'Dataset 4', 22: 'Dataset 3', 122: 'Dataset 4', 23: 'Dataset 3', 123: 'Dataset 4', 24: 'Dataset 3'}
# Running counter: {'Dataset 1': 10, 'Dataset 2': 123, 'Dataset 3': 208, 'Dataset 4': 203}
# Running percentages: {'Dataset 1': '1.8382352941176472%', 'Dataset 2': '22.610294117647058%', 'Dataset 3': '38.23529411764706%', 'Dataset 4': '37.31617647058824%'}
# --------------------------------------------------------------------------------
# Batch 18
# {24: 'Dataset 3', 25: 'Dataset 3', 125: 'Dataset 4', 26: 'Dataset 3', 126: 'Dataset 4', 7: 'Dataset 1', 27: 'Dataset 3', 127: 'Dataset 4', 28: 'Dataset 3', 128: 'Dataset 4', 29: 'Dataset 3', 129: 'Dataset 4', 30: 'Dataset 3', 31: 'Dataset 3', 131: 'Dataset 4'}
# Running counter: {'Dataset 1': 11, 'Dataset 2': 131, 'Dataset 3': 222, 'Dataset 4': 212}
# Running percentages: {'Dataset 1': '1.9097222222222223%', 'Dataset 2': '22.743055555555554%', 'Dataset 3': '38.54166666666667%', 'Dataset 4': '36.80555555555556%'}
# --------------------------------------------------------------------------------
# Batch 19
# {131: 'Dataset 4', 132: 'Dataset 4', 33: 'Dataset 3', 133: 'Dataset 4', 34: 'Dataset 3', 134: 'Dataset 4', 35: 'Dataset 3', 135: 'Dataset 4', 36: 'Dataset 3', 136: 'Dataset 4', 37: 'Dataset 3', 137: 'Dataset 4', 38: 'Dataset 3', 138: 'Dataset 4', 39: 'Dataset 3'}
# Running counter: {'Dataset 1': 11, 'Dataset 2': 137, 'Dataset 3': 232, 'Dataset 4': 228}
# Running percentages: {'Dataset 1': '1.8092105263157896%', 'Dataset 2': '22.532894736842106%', 'Dataset 3': '38.15789473684211%', 'Dataset 4': '37.5%'}
# --------------------------------------------------------------------------------
# Batch 20
# {39: 'Dataset 3', 139: 'Dataset 4', 0: 'Dataset 1', 40: 'Dataset 3', 140: 'Dataset 4', 41: 'Dataset 3', 141: 'Dataset 4', 42: 'Dataset 3', 43: 'Dataset 3', 143: 'Dataset 4', 44: 'Dataset 3', 144: 'Dataset 4', 45: 'Dataset 3', 145: 'Dataset 4', 46: 'Dataset 3'}
# Running counter: {'Dataset 1': 12, 'Dataset 2': 142, 'Dataset 3': 249, 'Dataset 4': 237}
# Running percentages: {'Dataset 1': '1.875%', 'Dataset 2': '22.1875%', 'Dataset 3': '38.90625%', 'Dataset 4': '37.03125%'}
# --------------------------------------------------------------------------------
# Batch 21
# {46: 'Dataset 3', 146: 'Dataset 4', 47: 'Dataset 3', 147: 'Dataset 4', 48: 'Dataset 3', 148: 'Dataset 4', 49: 'Dataset 3', 149: 'Dataset 4', 0: 'Dataset 2', 50: 'Dataset 3', 51: 'Dataset 3', 151: 'Dataset 4', 2: 'Dataset 2'}
# Running counter: {'Dataset 1': 12, 'Dataset 2': 150, 'Dataset 3': 262, 'Dataset 4': 248}
# Running percentages: {'Dataset 1': '1.7857142857142856%', 'Dataset 2': '22.321428571428573%', 'Dataset 3': '38.98809523809524%', 'Dataset 4': '36.904761904761905%'}
# --------------------------------------------------------------------------------
# Batch 22
# {2: 'Dataset 2', 52: 'Dataset 3', 152: 'Dataset 4', 3: 'Dataset 2', 53: 'Dataset 3', 153: 'Dataset 4', 4: 'Dataset 2', 54: 'Dataset 3', 154: 'Dataset 4', 155: 'Dataset 4', 56: 'Dataset 3', 156: 'Dataset 4', 7: 'Dataset 2', 57: 'Dataset 3', 157: 'Dataset 4', 8: 'Dataset 2'}
# Running counter: {'Dataset 1': 13, 'Dataset 2': 157, 'Dataset 3': 272, 'Dataset 4': 262}
# Running percentages: {'Dataset 1': '1.8465909090909092%', 'Dataset 2': '22.301136363636363%', 'Dataset 3': '38.63636363636363%', 'Dataset 4': '37.215909090909086%'}
# --------------------------------------------------------------------------------
# Batch 23
# {158: 'Dataset 4', 9: 'Dataset 2', 59: 'Dataset 3', 159: 'Dataset 4', 10: 'Dataset 2', 60: 'Dataset 3', 160: 'Dataset 4', 61: 'Dataset 3', 62: 'Dataset 3', 162: 'Dataset 4', 13: 'Dataset 2', 63: 'Dataset 3', 163: 'Dataset 4', 14: 'Dataset 2', 64: 'Dataset 3', 164: 'Dataset 4', 15: 'Dataset 2', 65: 'Dataset 3', 165: 'Dataset 4', 66: 'Dataset 3', 166: 'Dataset 4'}
# Running counter: {'Dataset 1': 13, 'Dataset 2': 164, 'Dataset 3': 285, 'Dataset 4': 274}
# Running percentages: {'Dataset 1': '1.766304347826087%', 'Dataset 2': '22.282608695652172%', 'Dataset 3': '38.72282608695652%', 'Dataset 4': '37.22826086956522%'}
# --------------------------------------------------------------------------------
# Batch 24
# {67: 'Dataset 3', 167: 'Dataset 4', 18: 'Dataset 2', 68: 'Dataset 3', 168: 'Dataset 4', 19: 'Dataset 2', 69: 'Dataset 3', 169: 'Dataset 4', 20: 'Dataset 2', 70: 'Dataset 3', 1: 'Dataset 1', 21: 'Dataset 2', 71: 'Dataset 3', 171: 'Dataset 4', 2: 'Dataset 1', 22: 'Dataset 2', 72: 'Dataset 3', 172: 'Dataset 4', 73: 'Dataset 3', 174: 'Dataset 4', 75: 'Dataset 3'}
# Running counter: {'Dataset 1': 15, 'Dataset 2': 170, 'Dataset 3': 295, 'Dataset 4': 288}
# Running percentages: {'Dataset 1': '1.953125%', 'Dataset 2': '22.135416666666664%', 'Dataset 3': '38.41145833333333%', 'Dataset 4': '37.5%'}
# --------------------------------------------------------------------------------
# Batch 25
# {75: 'Dataset 3', 175: 'Dataset 4', 26: 'Dataset 2', 76: 'Dataset 3', 176: 'Dataset 4', 27: 'Dataset 2', 77: 'Dataset 3', 177: 'Dataset 4', 28: 'Dataset 2', 78: 'Dataset 3', 178: 'Dataset 4', 79: 'Dataset 3', 179: 'Dataset 4', 30: 'Dataset 2', 80: 'Dataset 3', 180: 'Dataset 4', 181: 'Dataset 4', 32: 'Dataset 2', 82: 'Dataset 3'}
# Running counter: {'Dataset 1': 15, 'Dataset 2': 176, 'Dataset 3': 306, 'Dataset 4': 303}
# Running percentages: {'Dataset 1': '1.875%', 'Dataset 2': '22.0%', 'Dataset 3': '38.25%', 'Dataset 4': '37.875%'}
# --------------------------------------------------------------------------------
# Batch 26
# {33: 'Dataset 2', 83: 'Dataset 3', 84: 'Dataset 3', 5: 'Dataset 1', 185: 'Dataset 4', 86: 'Dataset 3', 186: 'Dataset 4', 187: 'Dataset 4', 38: 'Dataset 2', 88: 'Dataset 3', 39: 'Dataset 2', 189: 'Dataset 4', 90: 'Dataset 3', 190: 'Dataset 4', 91: 'Dataset 3', 191: 'Dataset 4', 92: 'Dataset 3'}
# Running counter: {'Dataset 1': 16, 'Dataset 2': 179, 'Dataset 3': 323, 'Dataset 4': 314}
# Running percentages: {'Dataset 1': '1.9230769230769231%', 'Dataset 2': '21.514423076923077%', 'Dataset 3': '38.82211538461539%', 'Dataset 4': '37.74038461538461%'}
# --------------------------------------------------------------------------------
# Batch 27
# {92: 'Dataset 3', 192: 'Dataset 4', 93: 'Dataset 3', 193: 'Dataset 4', 44: 'Dataset 2', 194: 'Dataset 4', 95: 'Dataset 3', 195: 'Dataset 4', 96: 'Dataset 3', 196: 'Dataset 4', 197: 'Dataset 4', 8: 'Dataset 1', 48: 'Dataset 2', 98: 'Dataset 3', 49: 'Dataset 2', 199: 'Dataset 4', 0: 'Dataset 3'}
# Running counter: {'Dataset 1': 17, 'Dataset 2': 183, 'Dataset 3': 338, 'Dataset 4': 326}
# Running percentages: {'Dataset 1': '1.9675925925925926%', 'Dataset 2': '21.180555555555554%', 'Dataset 3': '39.120370370370374%', 'Dataset 4': '37.73148148148148%'}
# --------------------------------------------------------------------------------
# Batch 28
# {0: 'Dataset 3', 1: 'Dataset 3', 201: 'Dataset 4', 2: 'Dataset 3', 202: 'Dataset 4', 3: 'Dataset 3', 203: 'Dataset 4', 4: 'Dataset 2', 204: 'Dataset 4', 5: 'Dataset 3', 205: 'Dataset 4', 6: 'Dataset 3', 206: 'Dataset 4', 7: 'Dataset 2'}
# Running counter: {'Dataset 1': 19, 'Dataset 2': 192, 'Dataset 3': 351, 'Dataset 4': 334}
# Running percentages: {'Dataset 1': '2.1205357142857144%', 'Dataset 2': '21.428571428571427%', 'Dataset 3': '39.174107142857146%', 'Dataset 4': '37.276785714285715%'}
# --------------------------------------------------------------------------------
# Batch 29
# {7: 'Dataset 1', 207: 'Dataset 4', 208: 'Dataset 4', 9: 'Dataset 3', 209: 'Dataset 4', 10: 'Dataset 3', 210: 'Dataset 4', 11: 'Dataset 3', 13: 'Dataset 3', 213: 'Dataset 4', 14: 'Dataset 3', 214: 'Dataset 4', 15: 'Dataset 2', 215: 'Dataset 4', 16: 'Dataset 3', 216: 'Dataset 4'}
# Running counter: {'Dataset 1': 21, 'Dataset 2': 199, 'Dataset 3': 361, 'Dataset 4': 347}
# Running percentages: {'Dataset 1': '2.2629310344827585%', 'Dataset 2': '21.443965517241377%', 'Dataset 3': '38.900862068965516%', 'Dataset 4': '37.39224137931034%'}
# --------------------------------------------------------------------------------
# Batch 30
# {17: 'Dataset 3', 217: 'Dataset 4', 18: 'Dataset 3', 218: 'Dataset 4', 9: 'Dataset 1', 19: 'Dataset 2', 20: 'Dataset 3', 220: 'Dataset 4', 21: 'Dataset 3', 221: 'Dataset 4', 222: 'Dataset 4', 23: 'Dataset 3', 223: 'Dataset 4', 24: 'Dataset 3', 25: 'Dataset 3'}
# Running counter: {'Dataset 1': 22, 'Dataset 2': 201, 'Dataset 3': 378, 'Dataset 4': 359}
# Running percentages: {'Dataset 1': '2.2916666666666665%', 'Dataset 2': '20.9375%', 'Dataset 3': '39.375%', 'Dataset 4': '37.395833333333336%'}
# --------------------------------------------------------------------------------
# Batch 31
# {25: 'Dataset 3', 225: 'Dataset 4', 26: 'Dataset 3', 227: 'Dataset 4', 28: 'Dataset 3', 228: 'Dataset 4', 29: 'Dataset 3', 229: 'Dataset 4', 30: 'Dataset 3', 231: 'Dataset 4', 32: 'Dataset 3', 232: 'Dataset 4', 3: 'Dataset 1', 33: 'Dataset 3'}
# Running counter: {'Dataset 1': 23, 'Dataset 2': 205, 'Dataset 3': 388, 'Dataset 4': 376}
# Running percentages: {'Dataset 1': '2.318548387096774%', 'Dataset 2': '20.665322580645164%', 'Dataset 3': '39.11290322580645%', 'Dataset 4': '37.903225806451616%'}
# --------------------------------------------------------------------------------
# Batch 32
# {33: 'Dataset 3', 233: 'Dataset 4', 34: 'Dataset 3', 234: 'Dataset 4', 35: 'Dataset 3', 235: 'Dataset 4', 6: 'Dataset 1', 36: 'Dataset 3', 37: 'Dataset 3', 237: 'Dataset 4', 38: 'Dataset 3', 238: 'Dataset 4', 39: 'Dataset 3', 239: 'Dataset 4', 40: 'Dataset 3', 240: 'Dataset 4'}
# Running counter: {'Dataset 1': 24, 'Dataset 2': 208, 'Dataset 3': 405, 'Dataset 4': 387}
# Running percentages: {'Dataset 1': '2.34375%', 'Dataset 2': '20.3125%', 'Dataset 3': '39.55078125%', 'Dataset 4': '37.79296875%'}
# --------------------------------------------------------------------------------
# Batch 33
# {41: 'Dataset 3', 241: 'Dataset 4', 2: 'Dataset 1', 42: 'Dataset 3', 242: 'Dataset 4', 43: 'Dataset 3', 44: 'Dataset 3', 45: 'Dataset 3', 245: 'Dataset 4', 46: 'Dataset 3', 246: 'Dataset 4', 247: 'Dataset 4', 248: 'Dataset 4', 49: 'Dataset 3', 50: 'Dataset 3'}
# Running counter: {'Dataset 1': 25, 'Dataset 2': 213, 'Dataset 3': 420, 'Dataset 4': 398}
# Running percentages: {'Dataset 1': '2.367424242424242%', 'Dataset 2': '20.170454545454543%', 'Dataset 3': '39.77272727272727%', 'Dataset 4': '37.68939393939394%'}
# --------------------------------------------------------------------------------
# Batch 34
# {50: 'Dataset 3', 250: 'Dataset 4', 251: 'Dataset 4', 2: 'Dataset 2', 52: 'Dataset 3', 252: 'Dataset 4', 53: 'Dataset 3', 253: 'Dataset 4', 4: 'Dataset 2', 54: 'Dataset 3', 55: 'Dataset 3', 255: 'Dataset 4', 6: 'Dataset 2', 56: 'Dataset 3', 256: 'Dataset 4'}
# Running counter: {'Dataset 1': 25, 'Dataset 2': 218, 'Dataset 3': 435, 'Dataset 4': 410}
# Running percentages: {'Dataset 1': '2.297794117647059%', 'Dataset 2': '20.036764705882355%', 'Dataset 3': '39.981617647058826%', 'Dataset 4': '37.68382352941176%'}
# --------------------------------------------------------------------------------
# Batch 35
# {7: 'Dataset 2', 57: 'Dataset 3', 8: 'Dataset 2', 58: 'Dataset 3', 258: 'Dataset 4', 9: 'Dataset 2', 59: 'Dataset 3', 259: 'Dataset 4', 10: 'Dataset 2', 60: 'Dataset 3', 260: 'Dataset 4', 11: 'Dataset 2', 61: 'Dataset 3', 261: 'Dataset 4', 12: 'Dataset 2', 262: 'Dataset 4', 13: 'Dataset 2', 263: 'Dataset 4', 14: 'Dataset 2'}
# Running counter: {'Dataset 1': 25, 'Dataset 2': 227, 'Dataset 3': 445, 'Dataset 4': 423}
# Running percentages: {'Dataset 1': '2.232142857142857%', 'Dataset 2': '20.267857142857142%', 'Dataset 3': '39.732142857142854%', 'Dataset 4': '37.76785714285714%'}
# --------------------------------------------------------------------------------
# Batch 36
# {64: 'Dataset 3', 264: 'Dataset 4', 65: 'Dataset 3', 265: 'Dataset 4', 16: 'Dataset 2', 66: 'Dataset 3', 266: 'Dataset 4', 17: 'Dataset 2', 67: 'Dataset 3', 267: 'Dataset 4', 18: 'Dataset 2', 68: 'Dataset 3', 268: 'Dataset 4', 69: 'Dataset 3', 269: 'Dataset 4'}
# Running counter: {'Dataset 1': 25, 'Dataset 2': 231, 'Dataset 3': 458, 'Dataset 4': 438}
# Running percentages: {'Dataset 1': '2.170138888888889%', 'Dataset 2': '20.052083333333336%', 'Dataset 3': '39.75694444444444%', 'Dataset 4': '38.02083333333333%'}
# --------------------------------------------------------------------------------
# Batch 37
# {269: 'Dataset 4', 70: 'Dataset 3', 270: 'Dataset 4', 21: 'Dataset 2', 71: 'Dataset 3', 22: 'Dataset 2', 272: 'Dataset 4', 23: 'Dataset 2', 73: 'Dataset 3', 273: 'Dataset 4', 74: 'Dataset 3', 274: 'Dataset 4', 5: 'Dataset 1', 25: 'Dataset 2', 75: 'Dataset 3', 275: 'Dataset 4', 26: 'Dataset 2', 76: 'Dataset 3', 276: 'Dataset 4', 7: 'Dataset 1', 27: 'Dataset 2', 77: 'Dataset 3'}
# Running counter: {'Dataset 1': 27, 'Dataset 2': 237, 'Dataset 3': 469, 'Dataset 4': 451}
# Running percentages: {'Dataset 1': '2.2804054054054053%', 'Dataset 2': '20.01689189189189%', 'Dataset 3': '39.611486486486484%', 'Dataset 4': '38.09121621621622%'}
# --------------------------------------------------------------------------------
# Batch 38
# {28: 'Dataset 2', 78: 'Dataset 3', 278: 'Dataset 4', 29: 'Dataset 2', 79: 'Dataset 3', 279: 'Dataset 4', 30: 'Dataset 2', 81: 'Dataset 3', 82: 'Dataset 3', 282: 'Dataset 4', 33: 'Dataset 2', 83: 'Dataset 3', 283: 'Dataset 4', 34: 'Dataset 2', 84: 'Dataset 3', 284: 'Dataset 4', 35: 'Dataset 2', 85: 'Dataset 3', 285: 'Dataset 4', 36: 'Dataset 2'}
# Running counter: {'Dataset 1': 27, 'Dataset 2': 247, 'Dataset 3': 483, 'Dataset 4': 459}
# Running percentages: {'Dataset 1': '2.2203947368421053%', 'Dataset 2': '20.3125%', 'Dataset 3': '39.72039473684211%', 'Dataset 4': '37.74671052631579%'}
# --------------------------------------------------------------------------------
# Batch 39
# {86: 'Dataset 3', 286: 'Dataset 4', 87: 'Dataset 3', 287: 'Dataset 4', 8: 'Dataset 1', 88: 'Dataset 3', 9: 'Dataset 1', 39: 'Dataset 2', 90: 'Dataset 3', 290: 'Dataset 4', 1: 'Dataset 1', 41: 'Dataset 2', 91: 'Dataset 3', 291: 'Dataset 4', 92: 'Dataset 3', 292: 'Dataset 4', 293: 'Dataset 4', 44: 'Dataset 2', 94: 'Dataset 3', 45: 'Dataset 2', 96: 'Dataset 3'}
# Running counter: {'Dataset 1': 30, 'Dataset 2': 251, 'Dataset 3': 498, 'Dataset 4': 469}
# Running percentages: {'Dataset 1': '2.403846153846154%', 'Dataset 2': '20.11217948717949%', 'Dataset 3': '39.90384615384615%', 'Dataset 4': '37.580128205128204%'}
# --------------------------------------------------------------------------------
# Batch 40
# {96: 'Dataset 3', 296: 'Dataset 4', 47: 'Dataset 2', 97: 'Dataset 3', 48: 'Dataset 2', 98: 'Dataset 3', 298: 'Dataset 4', 49: 'Dataset 2', 299: 'Dataset 4', 0: 'Dataset 3', 300: 'Dataset 4', 1: 'Dataset 3', 301: 'Dataset 4', 2: 'Dataset 2', 3: 'Dataset 3', 303: 'Dataset 4', 4: 'Dataset 3'}
# Running counter: {'Dataset 1': 30, 'Dataset 2': 257, 'Dataset 3': 513, 'Dataset 4': 480}
# Running percentages: {'Dataset 1': '2.34375%', 'Dataset 2': '20.078125%', 'Dataset 3': '40.078125%', 'Dataset 4': '37.5%'}
# --------------------------------------------------------------------------------
# Batch 41
# {304: 'Dataset 4', 5: 'Dataset 3', 305: 'Dataset 4', 6: 'Dataset 3', 306: 'Dataset 4', 7: 'Dataset 3', 307: 'Dataset 4', 8: 'Dataset 3', 308: 'Dataset 4', 9: 'Dataset 3', 309: 'Dataset 4', 10: 'Dataset 3', 310: 'Dataset 4', 11: 'Dataset 3', 311: 'Dataset 4'}
# Running counter: {'Dataset 1': 31, 'Dataset 2': 260, 'Dataset 3': 526, 'Dataset 4': 495}
# Running percentages: {'Dataset 1': '2.3628048780487805%', 'Dataset 2': '19.817073170731707%', 'Dataset 3': '40.09146341463415%', 'Dataset 4': '37.728658536585364%'}
# --------------------------------------------------------------------------------
# Batch 42
# {311: 'Dataset 4', 2: 'Dataset 1', 12: 'Dataset 3', 312: 'Dataset 4', 13: 'Dataset 3', 313: 'Dataset 4', 14: 'Dataset 3', 314: 'Dataset 4', 15: 'Dataset 3', 315: 'Dataset 4', 6: 'Dataset 1', 16: 'Dataset 3', 316: 'Dataset 4', 17: 'Dataset 3', 317: 'Dataset 4', 18: 'Dataset 3', 19: 'Dataset 3', 319: 'Dataset 4'}
# Running counter: {'Dataset 1': 33, 'Dataset 2': 262, 'Dataset 3': 540, 'Dataset 4': 509}
# Running percentages: {'Dataset 1': '2.455357142857143%', 'Dataset 2': '19.49404761904762%', 'Dataset 3': '40.17857142857143%', 'Dataset 4': '37.87202380952381%'}
# --------------------------------------------------------------------------------
# Batch 43
# {319: 'Dataset 4', 21: 'Dataset 3', 321: 'Dataset 4', 22: 'Dataset 3', 322: 'Dataset 4', 323: 'Dataset 4', 24: 'Dataset 3', 324: 'Dataset 4', 5: 'Dataset 1', 25: 'Dataset 3', 26: 'Dataset 3', 326: 'Dataset 4', 27: 'Dataset 3', 327: 'Dataset 4'}
# Running counter: {'Dataset 1': 34, 'Dataset 2': 266, 'Dataset 3': 554, 'Dataset 4': 522}
# Running percentages: {'Dataset 1': '2.4709302325581395%', 'Dataset 2': '19.331395348837212%', 'Dataset 3': '40.26162790697674%', 'Dataset 4': '37.93604651162791%'}
# --------------------------------------------------------------------------------
# Batch 44
# {327: 'Dataset 4', 28: 'Dataset 3', 29: 'Dataset 3', 30: 'Dataset 3', 31: 'Dataset 3', 331: 'Dataset 4', 32: 'Dataset 3', 333: 'Dataset 4', 34: 'Dataset 3', 334: 'Dataset 4', 335: 'Dataset 4', 36: 'Dataset 3'}
# Running counter: {'Dataset 1': 34, 'Dataset 2': 274, 'Dataset 3': 570, 'Dataset 4': 530}
# Running percentages: {'Dataset 1': '2.414772727272727%', 'Dataset 2': '19.460227272727273%', 'Dataset 3': '40.48295454545455%', 'Dataset 4': '37.64204545454545%'}
# --------------------------------------------------------------------------------
# Batch 45
# {36: 'Dataset 3', 336: 'Dataset 4', 37: 'Dataset 3', 337: 'Dataset 4', 38: 'Dataset 3', 39: 'Dataset 2', 339: 'Dataset 4', 40: 'Dataset 3', 340: 'Dataset 4', 41: 'Dataset 3', 342: 'Dataset 4', 43: 'Dataset 3', 343: 'Dataset 4', 4: 'Dataset 1', 44: 'Dataset 2'}
# Running counter: {'Dataset 1': 35, 'Dataset 2': 281, 'Dataset 3': 580, 'Dataset 4': 544}
# Running percentages: {'Dataset 1': '2.430555555555556%', 'Dataset 2': '19.51388888888889%', 'Dataset 3': '40.27777777777778%', 'Dataset 4': '37.77777777777778%'}
# --------------------------------------------------------------------------------
# Batch 46
# {44: 'Dataset 2', 344: 'Dataset 4', 45: 'Dataset 2', 345: 'Dataset 4', 46: 'Dataset 3', 346: 'Dataset 4', 47: 'Dataset 3', 347: 'Dataset 4', 48: 'Dataset 3', 348: 'Dataset 4', 49: 'Dataset 3', 349: 'Dataset 4', 50: 'Dataset 3', 350: 'Dataset 4'}
# Running counter: {'Dataset 1': 35, 'Dataset 2': 287, 'Dataset 3': 591, 'Dataset 4': 559}
# Running percentages: {'Dataset 1': '2.377717391304348%', 'Dataset 2': '19.497282608695652%', 'Dataset 3': '40.14945652173913%', 'Dataset 4': '37.97554347826087%'}
# --------------------------------------------------------------------------------
# Batch 47
# {52: 'Dataset 3', 352: 'Dataset 4', 3: 'Dataset 2', 53: 'Dataset 3', 353: 'Dataset 4', 54: 'Dataset 3', 354: 'Dataset 4', 5: 'Dataset 2', 55: 'Dataset 3', 355: 'Dataset 4', 6: 'Dataset 2', 56: 'Dataset 3', 356: 'Dataset 4', 7: 'Dataset 2', 357: 'Dataset 4', 8: 'Dataset 2', 58: 'Dataset 3'}
# Running counter: {'Dataset 1': 36, 'Dataset 2': 296, 'Dataset 3': 601, 'Dataset 4': 571}
# Running percentages: {'Dataset 1': '2.393617021276596%', 'Dataset 2': '19.680851063829788%', 'Dataset 3': '39.96010638297872%', 'Dataset 4': '37.965425531914896%'}
# --------------------------------------------------------------------------------
# Batch 48
# {358: 'Dataset 4', 59: 'Dataset 3', 359: 'Dataset 4', 10: 'Dataset 2', 60: 'Dataset 3', 360: 'Dataset 4', 11: 'Dataset 2', 61: 'Dataset 3', 2: 'Dataset 1', 62: 'Dataset 3', 362: 'Dataset 4', 63: 'Dataset 3', 363: 'Dataset 4', 14: 'Dataset 2', 64: 'Dataset 3', 364: 'Dataset 4', 15: 'Dataset 2', 65: 'Dataset 3'}
# Running counter: {'Dataset 1': 38, 'Dataset 2': 303, 'Dataset 3': 614, 'Dataset 4': 581}
# Running percentages: {'Dataset 1': '2.473958333333333%', 'Dataset 2': '19.7265625%', 'Dataset 3': '39.97395833333333%', 'Dataset 4': '37.82552083333333%'}
# --------------------------------------------------------------------------------
# Batch 49
# {365: 'Dataset 4', 16: 'Dataset 2', 66: 'Dataset 3', 17: 'Dataset 2', 67: 'Dataset 3', 367: 'Dataset 4', 18: 'Dataset 2', 68: 'Dataset 3', 368: 'Dataset 4', 9: 'Dataset 1', 19: 'Dataset 2', 69: 'Dataset 3', 369: 'Dataset 4', 20: 'Dataset 2', 21: 'Dataset 2', 71: 'Dataset 3', 371: 'Dataset 4', 72: 'Dataset 3', 73: 'Dataset 3', 373: 'Dataset 4', 24: 'Dataset 2'}
# Running counter: {'Dataset 1': 39, 'Dataset 2': 310, 'Dataset 3': 630, 'Dataset 4': 589}
# Running percentages: {'Dataset 1': '2.4872448979591835%', 'Dataset 2': '19.77040816326531%', 'Dataset 3': '40.17857142857143%', 'Dataset 4': '37.56377551020408%'}
# --------------------------------------------------------------------------------
# Batch 50
# {74: 'Dataset 3', 75: 'Dataset 3', 375: 'Dataset 4', 26: 'Dataset 2', 76: 'Dataset 3', 376: 'Dataset 4', 7: 'Dataset 1', 377: 'Dataset 4', 378: 'Dataset 4', 30: 'Dataset 2', 80: 'Dataset 3', 81: 'Dataset 3', 82: 'Dataset 3', 33: 'Dataset 2', 83: 'Dataset 3', 383: 'Dataset 4'}
# Running counter: {'Dataset 1': 40, 'Dataset 2': 315, 'Dataset 3': 646, 'Dataset 4': 599}
# Running percentages: {'Dataset 1': '2.5%', 'Dataset 2': '19.6875%', 'Dataset 3': '40.375%', 'Dataset 4': '37.4375%'}
# --------------------------------------------------------------------------------
# Batch 51
# {4: 'Dataset 1', 34: 'Dataset 2', 384: 'Dataset 4', 385: 'Dataset 4', 36: 'Dataset 2', 86: 'Dataset 3', 386: 'Dataset 4', 88: 'Dataset 3', 388: 'Dataset 4', 39: 'Dataset 2', 89: 'Dataset 3', 389: 'Dataset 4', 40: 'Dataset 2', 390: 'Dataset 4', 41: 'Dataset 2', 91: 'Dataset 3', 391: 'Dataset 4', 42: 'Dataset 2', 92: 'Dataset 3', 392: 'Dataset 4', 3: 'Dataset 1', 393: 'Dataset 4'}
# Running counter: {'Dataset 1': 42, 'Dataset 2': 321, 'Dataset 3': 655, 'Dataset 4': 614}
# Running percentages: {'Dataset 1': '2.5735294117647056%', 'Dataset 2': '19.669117647058822%', 'Dataset 3': '40.13480392156863%', 'Dataset 4': '37.622549019607845%'}
# --------------------------------------------------------------------------------
# Batch 52
# {393: 'Dataset 4', 4: 'Dataset 1', 94: 'Dataset 3', 394: 'Dataset 4', 95: 'Dataset 3', 395: 'Dataset 4', 96: 'Dataset 3', 396: 'Dataset 4', 47: 'Dataset 2', 97: 'Dataset 3', 397: 'Dataset 4', 48: 'Dataset 2', 98: 'Dataset 3', 398: 'Dataset 4', 99: 'Dataset 3', 399: 'Dataset 4', 0: 'Dataset 2'}
# Running counter: {'Dataset 1': 43, 'Dataset 2': 325, 'Dataset 3': 667, 'Dataset 4': 629}
# Running percentages: {'Dataset 1': '2.5841346153846154%', 'Dataset 2': '19.53125%', 'Dataset 3': '40.08413461538461%', 'Dataset 4': '37.800480769230774%'}
# --------------------------------------------------------------------------------
# Batch 53
# {0: 'Dataset 3', 400: 'Dataset 4', 1: 'Dataset 2', 401: 'Dataset 4', 2: 'Dataset 2', 402: 'Dataset 4', 3: 'Dataset 3', 403: 'Dataset 4', 4: 'Dataset 3', 404: 'Dataset 4', 5: 'Dataset 3'}
# Running counter: {'Dataset 1': 45, 'Dataset 2': 333, 'Dataset 3': 674, 'Dataset 4': 644}
# Running percentages: {'Dataset 1': '2.6533018867924527%', 'Dataset 2': '19.63443396226415%', 'Dataset 3': '39.740566037735846%', 'Dataset 4': '37.971698113207545%'}
# --------------------------------------------------------------------------------
# Batch 54
# {5: 'Dataset 3', 405: 'Dataset 4', 6: 'Dataset 3', 406: 'Dataset 4', 7: 'Dataset 2', 407: 'Dataset 4', 8: 'Dataset 3', 408: 'Dataset 4', 9: 'Dataset 3', 409: 'Dataset 4', 10: 'Dataset 3', 410: 'Dataset 4', 11: 'Dataset 3'}
# Running counter: {'Dataset 1': 45, 'Dataset 2': 335, 'Dataset 3': 688, 'Dataset 4': 660}
# Running percentages: {'Dataset 1': '2.604166666666667%', 'Dataset 2': '19.386574074074073%', 'Dataset 3': '39.81481481481482%', 'Dataset 4': '38.19444444444444%'}
# --------------------------------------------------------------------------------
# Batch 55
# {411: 'Dataset 4', 12: 'Dataset 3', 13: 'Dataset 3', 413: 'Dataset 4', 14: 'Dataset 3', 15: 'Dataset 3', 6: 'Dataset 1', 16: 'Dataset 3', 416: 'Dataset 4', 17: 'Dataset 2', 18: 'Dataset 3', 19: 'Dataset 3', 419: 'Dataset 4'}
# Running counter: {'Dataset 1': 46, 'Dataset 2': 341, 'Dataset 3': 706, 'Dataset 4': 667}
# Running percentages: {'Dataset 1': '2.6136363636363633%', 'Dataset 2': '19.375%', 'Dataset 3': '40.11363636363636%', 'Dataset 4': '37.89772727272727%'}
# --------------------------------------------------------------------------------
# Batch 56
# {419: 'Dataset 4', 20: 'Dataset 3', 420: 'Dataset 4', 21: 'Dataset 3', 421: 'Dataset 4', 22: 'Dataset 3', 422: 'Dataset 4', 23: 'Dataset 3', 423: 'Dataset 4', 24: 'Dataset 3', 424: 'Dataset 4', 25: 'Dataset 3', 425: 'Dataset 4'}
# Running counter: {'Dataset 1': 46, 'Dataset 2': 347, 'Dataset 3': 718, 'Dataset 4': 681}
# Running percentages: {'Dataset 1': '2.5669642857142856%', 'Dataset 2': '19.363839285714285%', 'Dataset 3': '40.066964285714285%', 'Dataset 4': '38.002232142857146%'}
# --------------------------------------------------------------------------------
# Batch 57
# {425: 'Dataset 4', 26: 'Dataset 3', 426: 'Dataset 4', 27: 'Dataset 3', 427: 'Dataset 4', 28: 'Dataset 3', 428: 'Dataset 4', 29: 'Dataset 3', 429: 'Dataset 4', 30: 'Dataset 3', 430: 'Dataset 4', 31: 'Dataset 3'}
# Running counter: {'Dataset 1': 46, 'Dataset 2': 350, 'Dataset 3': 734, 'Dataset 4': 694}
# Running percentages: {'Dataset 1': '2.5219298245614032%', 'Dataset 2': '19.188596491228072%', 'Dataset 3': '40.24122807017544%', 'Dataset 4': '38.04824561403509%'}
# --------------------------------------------------------------------------------
# Batch 58
# {31: 'Dataset 3', 431: 'Dataset 4', 2: 'Dataset 1', 32: 'Dataset 3', 33: 'Dataset 3', 433: 'Dataset 4', 34: 'Dataset 3', 434: 'Dataset 4', 35: 'Dataset 3', 435: 'Dataset 4', 36: 'Dataset 3', 436: 'Dataset 4', 37: 'Dataset 2', 437: 'Dataset 4', 38: 'Dataset 3', 438: 'Dataset 4', 39: 'Dataset 3'}
# Running counter: {'Dataset 1': 47, 'Dataset 2': 355, 'Dataset 3': 750, 'Dataset 4': 704}
# Running percentages: {'Dataset 1': '2.5323275862068964%', 'Dataset 2': '19.127155172413794%', 'Dataset 3': '40.40948275862069%', 'Dataset 4': '37.93103448275862%'}
# --------------------------------------------------------------------------------
# Batch 59
# {439: 'Dataset 4', 0: 'Dataset 1', 40: 'Dataset 3', 41: 'Dataset 2', 42: 'Dataset 3', 442: 'Dataset 4', 43: 'Dataset 3', 443: 'Dataset 4', 4: 'Dataset 1', 44: 'Dataset 3', 444: 'Dataset 4', 5: 'Dataset 1', 45: 'Dataset 3'}
# Running counter: {'Dataset 1': 50, 'Dataset 2': 362, 'Dataset 3': 759, 'Dataset 4': 717}
# Running percentages: {'Dataset 1': '2.6483050847457625%', 'Dataset 2': '19.173728813559322%', 'Dataset 3': '40.20127118644068%', 'Dataset 4': '37.97669491525424%'}
# --------------------------------------------------------------------------------
# Batch 60
# {445: 'Dataset 4', 6: 'Dataset 1', 46: 'Dataset 3', 47: 'Dataset 3', 48: 'Dataset 3', 448: 'Dataset 4', 49: 'Dataset 3', 449: 'Dataset 4', 50: 'Dataset 3', 450: 'Dataset 4', 451: 'Dataset 4', 52: 'Dataset 3'}
# Running counter: {'Dataset 1': 51, 'Dataset 2': 364, 'Dataset 3': 775, 'Dataset 4': 730}
# Running percentages: {'Dataset 1': '2.65625%', 'Dataset 2': '18.958333333333332%', 'Dataset 3': '40.36458333333333%', 'Dataset 4': '38.02083333333333%'}
# --------------------------------------------------------------------------------
# Batch 61
# {52: 'Dataset 3', 452: 'Dataset 4', 53: 'Dataset 3', 453: 'Dataset 4', 54: 'Dataset 3', 5: 'Dataset 2', 6: 'Dataset 2', 456: 'Dataset 4', 57: 'Dataset 3', 457: 'Dataset 4', 8: 'Dataset 2', 458: 'Dataset 4', 459: 'Dataset 4', 10: 'Dataset 2', 60: 'Dataset 3', 61: 'Dataset 3', 461: 'Dataset 4', 62: 'Dataset 3', 462: 'Dataset 4', 63: 'Dataset 3'}
# Running counter: {'Dataset 1': 51, 'Dataset 2': 369, 'Dataset 3': 791, 'Dataset 4': 741}
# Running percentages: {'Dataset 1': '2.612704918032787%', 'Dataset 2': '18.903688524590166%', 'Dataset 3': '40.52254098360656%', 'Dataset 4': '37.96106557377049%'}
# --------------------------------------------------------------------------------
# Batch 62
# {63: 'Dataset 3', 15: 'Dataset 2', 65: 'Dataset 3', 465: 'Dataset 4', 66: 'Dataset 3', 466: 'Dataset 4', 17: 'Dataset 2', 67: 'Dataset 3', 467: 'Dataset 4', 18: 'Dataset 2', 68: 'Dataset 3', 468: 'Dataset 4', 19: 'Dataset 2', 469: 'Dataset 4', 70: 'Dataset 3', 470: 'Dataset 4', 21: 'Dataset 2', 71: 'Dataset 3', 471: 'Dataset 4'}
# Running counter: {'Dataset 1': 51, 'Dataset 2': 376, 'Dataset 3': 805, 'Dataset 4': 752}
# Running percentages: {'Dataset 1': '2.5705645161290325%', 'Dataset 2': '18.951612903225808%', 'Dataset 3': '40.57459677419355%', 'Dataset 4': '37.903225806451616%'}
# --------------------------------------------------------------------------------
# Batch 63
# {471: 'Dataset 4', 22: 'Dataset 2', 72: 'Dataset 3', 472: 'Dataset 4', 73: 'Dataset 3', 473: 'Dataset 4', 24: 'Dataset 2', 74: 'Dataset 3', 474: 'Dataset 4', 5: 'Dataset 1', 75: 'Dataset 3', 475: 'Dataset 4', 26: 'Dataset 2', 76: 'Dataset 3', 476: 'Dataset 4', 77: 'Dataset 3', 28: 'Dataset 2', 78: 'Dataset 3'}
# Running counter: {'Dataset 1': 52, 'Dataset 2': 380, 'Dataset 3': 816, 'Dataset 4': 768}
# Running percentages: {'Dataset 1': '2.579365079365079%', 'Dataset 2': '18.849206349206348%', 'Dataset 3': '40.476190476190474%', 'Dataset 4': '38.095238095238095%'}
# --------------------------------------------------------------------------------
# Batch 64
# {478: 'Dataset 4', 30: 'Dataset 2', 80: 'Dataset 3', 480: 'Dataset 4', 2: 'Dataset 1', 32: 'Dataset 2', 82: 'Dataset 3', 482: 'Dataset 4', 33: 'Dataset 2', 83: 'Dataset 3', 483: 'Dataset 4', 484: 'Dataset 4', 35: 'Dataset 2', 485: 'Dataset 4', 86: 'Dataset 3'}
# Running counter: {'Dataset 1': 53, 'Dataset 2': 388, 'Dataset 3': 825, 'Dataset 4': 782}
# Running percentages: {'Dataset 1': '2.587890625%', 'Dataset 2': '18.9453125%', 'Dataset 3': '40.283203125%', 'Dataset 4': '38.18359375%'}
# --------------------------------------------------------------------------------
# Batch 65
# {86: 'Dataset 3', 486: 'Dataset 4', 87: 'Dataset 3', 487: 'Dataset 4', 88: 'Dataset 3', 39: 'Dataset 2', 89: 'Dataset 3', 489: 'Dataset 4', 40: 'Dataset 2', 90: 'Dataset 3', 490: 'Dataset 4', 41: 'Dataset 2', 91: 'Dataset 3', 491: 'Dataset 4', 42: 'Dataset 2', 492: 'Dataset 4', 43: 'Dataset 2', 93: 'Dataset 3', 493: 'Dataset 4', 44: 'Dataset 2'}
# Running counter: {'Dataset 1': 53, 'Dataset 2': 398, 'Dataset 3': 836, 'Dataset 4': 793}
# Running percentages: {'Dataset 1': '2.548076923076923%', 'Dataset 2': '19.134615384615383%', 'Dataset 3': '40.19230769230769%', 'Dataset 4': '38.125%'}
# --------------------------------------------------------------------------------
# Batch 66
# {94: 'Dataset 3', 494: 'Dataset 4', 45: 'Dataset 2', 95: 'Dataset 3', 495: 'Dataset 4', 46: 'Dataset 2', 96: 'Dataset 3', 496: 'Dataset 4', 47: 'Dataset 2', 497: 'Dataset 4', 48: 'Dataset 2', 98: 'Dataset 3', 498: 'Dataset 4', 99: 'Dataset 3', 499: 'Dataset 4', 0: 'Dataset 3', 500: 'Dataset 4', 1: 'Dataset 3', 501: 'Dataset 4', 502: 'Dataset 4', 3: 'Dataset 3', 503: 'Dataset 4', 4: 'Dataset 1'}
# Running counter: {'Dataset 1': 54, 'Dataset 2': 403, 'Dataset 3': 849, 'Dataset 4': 806}
# Running percentages: {'Dataset 1': '2.556818181818182%', 'Dataset 2': '19.081439393939394%', 'Dataset 3': '40.19886363636363%', 'Dataset 4': '38.16287878787879%'}
# --------------------------------------------------------------------------------
# Batch 67
# {4: 'Dataset 3', 504: 'Dataset 4', 5: 'Dataset 3', 505: 'Dataset 4', 6: 'Dataset 3', 506: 'Dataset 4', 7: 'Dataset 3', 8: 'Dataset 3', 508: 'Dataset 4', 9: 'Dataset 3', 509: 'Dataset 4', 10: 'Dataset 3', 510: 'Dataset 4', 11: 'Dataset 2', 511: 'Dataset 4', 12: 'Dataset 2', 512: 'Dataset 4'}
# Running counter: {'Dataset 1': 55, 'Dataset 2': 409, 'Dataset 3': 857, 'Dataset 4': 823}
# Running percentages: {'Dataset 1': '2.565298507462687%', 'Dataset 2': '19.076492537313435%', 'Dataset 3': '39.97201492537313%', 'Dataset 4': '38.38619402985074%'}
# --------------------------------------------------------------------------------
# Batch 68
# {13: 'Dataset 3', 14: 'Dataset 3', 514: 'Dataset 4', 5: 'Dataset 1', 15: 'Dataset 3', 515: 'Dataset 4', 16: 'Dataset 3', 516: 'Dataset 4', 17: 'Dataset 3', 517: 'Dataset 4', 18: 'Dataset 2', 19: 'Dataset 3', 20: 'Dataset 3', 21: 'Dataset 3', 521: 'Dataset 4'}
# Running counter: {'Dataset 1': 56, 'Dataset 2': 418, 'Dataset 3': 868, 'Dataset 4': 834}
# Running percentages: {'Dataset 1': '2.5735294117647056%', 'Dataset 2': '19.209558823529413%', 'Dataset 3': '39.88970588235294%', 'Dataset 4': '38.32720588235294%'}
# --------------------------------------------------------------------------------
# Batch 69
# {521: 'Dataset 4', 22: 'Dataset 3', 522: 'Dataset 4', 24: 'Dataset 3', 524: 'Dataset 4', 25: 'Dataset 3', 525: 'Dataset 4', 26: 'Dataset 3', 526: 'Dataset 4', 527: 'Dataset 4', 28: 'Dataset 2', 528: 'Dataset 4', 9: 'Dataset 1', 29: 'Dataset 3', 529: 'Dataset 4', 30: 'Dataset 3', 530: 'Dataset 4', 31: 'Dataset 2'}
# Running counter: {'Dataset 1': 57, 'Dataset 2': 423, 'Dataset 3': 880, 'Dataset 4': 848}
# Running percentages: {'Dataset 1': '2.5815217391304346%', 'Dataset 2': '19.157608695652172%', 'Dataset 3': '39.85507246376812%', 'Dataset 4': '38.405797101449274%'}
# --------------------------------------------------------------------------------
# Batch 70
# {31: 'Dataset 3', 531: 'Dataset 4', 32: 'Dataset 3', 532: 'Dataset 4', 33: 'Dataset 3', 533: 'Dataset 4', 34: 'Dataset 2', 534: 'Dataset 4', 35: 'Dataset 3', 535: 'Dataset 4', 36: 'Dataset 3', 536: 'Dataset 4', 37: 'Dataset 3'}
# Running counter: {'Dataset 1': 57, 'Dataset 2': 431, 'Dataset 3': 894, 'Dataset 4': 858}
# Running percentages: {'Dataset 1': '2.544642857142857%', 'Dataset 2': '19.24107142857143%', 'Dataset 3': '39.91071428571429%', 'Dataset 4': '38.30357142857143%'}
# --------------------------------------------------------------------------------
# Batch 71
# {37: 'Dataset 3', 537: 'Dataset 4', 38: 'Dataset 3', 40: 'Dataset 3', 41: 'Dataset 3', 541: 'Dataset 4', 42: 'Dataset 3', 542: 'Dataset 4', 43: 'Dataset 3', 543: 'Dataset 4', 44: 'Dataset 2', 544: 'Dataset 4', 5: 'Dataset 1', 45: 'Dataset 3'}
# Running counter: {'Dataset 1': 58, 'Dataset 2': 438, 'Dataset 3': 907, 'Dataset 4': 869}
# Running percentages: {'Dataset 1': '2.552816901408451%', 'Dataset 2': '19.278169014084508%', 'Dataset 3': '39.92077464788733%', 'Dataset 4': '38.24823943661972%'}
# --------------------------------------------------------------------------------
# Batch 72
# {45: 'Dataset 3', 6: 'Dataset 1', 546: 'Dataset 4', 47: 'Dataset 3', 547: 'Dataset 4', 48: 'Dataset 3', 548: 'Dataset 4', 9: 'Dataset 1', 49: 'Dataset 3', 0: 'Dataset 1', 50: 'Dataset 3', 51: 'Dataset 3', 2: 'Dataset 2', 52: 'Dataset 3', 552: 'Dataset 4', 3: 'Dataset 2', 53: 'Dataset 3', 553: 'Dataset 4', 4: 'Dataset 2', 54: 'Dataset 3'}
# Running counter: {'Dataset 1': 61, 'Dataset 2': 445, 'Dataset 3': 919, 'Dataset 4': 879}
# Running percentages: {'Dataset 1': '2.647569444444444%', 'Dataset 2': '19.31423611111111%', 'Dataset 3': '39.88715277777778%', 'Dataset 4': '38.15104166666667%'}
# --------------------------------------------------------------------------------
# Batch 73
# {554: 'Dataset 4', 5: 'Dataset 1', 55: 'Dataset 3', 555: 'Dataset 4', 6: 'Dataset 2', 56: 'Dataset 3', 7: 'Dataset 2', 57: 'Dataset 3', 58: 'Dataset 3', 558: 'Dataset 4', 9: 'Dataset 2', 59: 'Dataset 3', 60: 'Dataset 3', 560: 'Dataset 4', 61: 'Dataset 3', 12: 'Dataset 2', 62: 'Dataset 3', 562: 'Dataset 4', 63: 'Dataset 3', 563: 'Dataset 4', 14: 'Dataset 2', 64: 'Dataset 3'}
# Running counter: {'Dataset 1': 62, 'Dataset 2': 453, 'Dataset 3': 933, 'Dataset 4': 888}
# Running percentages: {'Dataset 1': '2.654109589041096%', 'Dataset 2': '19.392123287671232%', 'Dataset 3': '39.94006849315068%', 'Dataset 4': '38.013698630136986%'}
# --------------------------------------------------------------------------------
# Batch 74
# {64: 'Dataset 3', 15: 'Dataset 2', 65: 'Dataset 3', 565: 'Dataset 4', 16: 'Dataset 2', 17: 'Dataset 2', 67: 'Dataset 3', 567: 'Dataset 4', 68: 'Dataset 3', 568: 'Dataset 4', 9: 'Dataset 1', 69: 'Dataset 3', 569: 'Dataset 4', 70: 'Dataset 3', 570: 'Dataset 4', 1: 'Dataset 1', 71: 'Dataset 3', 571: 'Dataset 4'}
# Running counter: {'Dataset 1': 64, 'Dataset 2': 457, 'Dataset 3': 946, 'Dataset 4': 901}
# Running percentages: {'Dataset 1': '2.7027027027027026%', 'Dataset 2': '19.298986486486484%', 'Dataset 3': '39.94932432432432%', 'Dataset 4': '38.048986486486484%'}
# --------------------------------------------------------------------------------
# Batch 75
# {22: 'Dataset 2', 72: 'Dataset 3', 572: 'Dataset 4', 23: 'Dataset 2', 73: 'Dataset 3', 573: 'Dataset 4', 4: 'Dataset 1', 74: 'Dataset 3', 574: 'Dataset 4', 75: 'Dataset 3', 26: 'Dataset 2', 76: 'Dataset 3', 77: 'Dataset 3', 577: 'Dataset 4', 78: 'Dataset 3', 578: 'Dataset 4', 29: 'Dataset 2', 79: 'Dataset 3', 579: 'Dataset 4'}
# Running counter: {'Dataset 1': 65, 'Dataset 2': 464, 'Dataset 3': 960, 'Dataset 4': 911}
# Running percentages: {'Dataset 1': '2.7083333333333335%', 'Dataset 2': '19.333333333333332%', 'Dataset 3': '40.0%', 'Dataset 4': '37.958333333333336%'}
# --------------------------------------------------------------------------------
# Batch 76
# {80: 'Dataset 3', 580: 'Dataset 4', 1: 'Dataset 1', 31: 'Dataset 2', 81: 'Dataset 3', 581: 'Dataset 4', 82: 'Dataset 3', 582: 'Dataset 4', 33: 'Dataset 2', 83: 'Dataset 3', 583: 'Dataset 4', 34: 'Dataset 2', 84: 'Dataset 3', 35: 'Dataset 2', 85: 'Dataset 3', 585: 'Dataset 4', 586: 'Dataset 4', 7: 'Dataset 1', 37: 'Dataset 2', 87: 'Dataset 3'}
# Running counter: {'Dataset 1': 67, 'Dataset 2': 472, 'Dataset 3': 973, 'Dataset 4': 920}
# Running percentages: {'Dataset 1': '2.7549342105263155%', 'Dataset 2': '19.407894736842106%', 'Dataset 3': '40.00822368421053%', 'Dataset 4': '37.82894736842105%'}
# --------------------------------------------------------------------------------
# Batch 77
# {87: 'Dataset 3', 587: 'Dataset 4', 38: 'Dataset 2', 88: 'Dataset 3', 39: 'Dataset 2', 89: 'Dataset 3', 589: 'Dataset 4', 40: 'Dataset 2', 90: 'Dataset 3', 590: 'Dataset 4', 91: 'Dataset 3', 591: 'Dataset 4', 92: 'Dataset 3', 592: 'Dataset 4', 43: 'Dataset 2', 94: 'Dataset 3', 594: 'Dataset 4', 45: 'Dataset 2', 95: 'Dataset 3', 595: 'Dataset 4'}
# Running counter: {'Dataset 1': 67, 'Dataset 2': 479, 'Dataset 3': 988, 'Dataset 4': 930}
# Running percentages: {'Dataset 1': '2.719155844155844%', 'Dataset 2': '19.439935064935064%', 'Dataset 3': '40.0974025974026%', 'Dataset 4': '37.743506493506494%'}
# --------------------------------------------------------------------------------
# Batch 78
# {595: 'Dataset 4', 96: 'Dataset 3', 596: 'Dataset 4', 47: 'Dataset 2', 597: 'Dataset 4', 98: 'Dataset 3', 49: 'Dataset 2', 99: 'Dataset 3', 599: 'Dataset 4', 0: 'Dataset 2', 600: 'Dataset 4', 601: 'Dataset 4', 2: 'Dataset 3', 3: 'Dataset 3', 4: 'Dataset 3', 604: 'Dataset 4'}
# Running counter: {'Dataset 1': 68, 'Dataset 2': 486, 'Dataset 3': 998, 'Dataset 4': 944}
# Running percentages: {'Dataset 1': '2.7243589743589745%', 'Dataset 2': '19.471153846153847%', 'Dataset 3': '39.983974358974365%', 'Dataset 4': '37.82051282051282%'}
# --------------------------------------------------------------------------------
# Batch 79
# {5: 'Dataset 3', 605: 'Dataset 4', 6: 'Dataset 3', 606: 'Dataset 4', 607: 'Dataset 4', 8: 'Dataset 3', 608: 'Dataset 4', 9: 'Dataset 3', 10: 'Dataset 3', 610: 'Dataset 4', 1: 'Dataset 1', 11: 'Dataset 3', 2: 'Dataset 1', 12: 'Dataset 2'}
# Running counter: {'Dataset 1': 71, 'Dataset 2': 492, 'Dataset 3': 1012, 'Dataset 4': 953}
# Running percentages: {'Dataset 1': '2.8085443037974684%', 'Dataset 2': '19.462025316455698%', 'Dataset 3': '40.03164556962025%', 'Dataset 4': '37.697784810126585%'}
# --------------------------------------------------------------------------------
# Batch 80
# {12: 'Dataset 3', 612: 'Dataset 4', 13: 'Dataset 3', 613: 'Dataset 4', 14: 'Dataset 3', 614: 'Dataset 4', 15: 'Dataset 3', 615: 'Dataset 4', 16: 'Dataset 3', 17: 'Dataset 3', 617: 'Dataset 4', 18: 'Dataset 3'}
# Running counter: {'Dataset 1': 71, 'Dataset 2': 500, 'Dataset 3': 1025, 'Dataset 4': 964}
# Running percentages: {'Dataset 1': '2.7734375%', 'Dataset 2': '19.53125%', 'Dataset 3': '40.0390625%', 'Dataset 4': '37.65625%'}
# --------------------------------------------------------------------------------
# Batch 81
# ...
# Running counter: {'Dataset 1': 958, 'Dataset 2': 5958, 'Dataset 3': 12196, 'Dataset 4': 12088}
# Running percentages: {'Dataset 1': '3.0705128205128203%', 'Dataset 2': '19.096153846153847%', 'Dataset 3': '39.08974358974359%', 'Dataset 4': '38.743589743589745%'}
# --------------------------------------------------------------------------------
# Batch 976
# {67: 'Dataset 3', 767: 'Dataset 4', 18: 'Dataset 2', 68: 'Dataset 3', 768: 'Dataset 4', 69: 'Dataset 3', 769: 'Dataset 4', 0: 'Dataset 1', 70: 'Dataset 3', 770: 'Dataset 4', 21: 'Dataset 2', 71: 'Dataset 3', 771: 'Dataset 4', 22: 'Dataset 2', 772: 'Dataset 4', 3: 'Dataset 1', 23: 'Dataset 2', 73: 'Dataset 3', 773: 'Dataset 4', 74: 'Dataset 3'}
# Running counter: {'Dataset 1': 960, 'Dataset 2': 5964, 'Dataset 3': 12206, 'Dataset 4': 12102}
# Running percentages: {'Dataset 1': '3.0737704918032787%', 'Dataset 2': '19.09579918032787%', 'Dataset 3': '39.08171106557377%', 'Dataset 4': '38.74871926229508%'}
# --------------------------------------------------------------------------------
# Batch 977
# {74: 'Dataset 3', 774: 'Dataset 4', 75: 'Dataset 3', 775: 'Dataset 4', 26: 'Dataset 2', 76: 'Dataset 3', 776: 'Dataset 4', 27: 'Dataset 2', 77: 'Dataset 3', 777: 'Dataset 4', 8: 'Dataset 1', 28: 'Dataset 2', 778: 'Dataset 4', 9: 'Dataset 1', 29: 'Dataset 2', 30: 'Dataset 2', 80: 'Dataset 3', 780: 'Dataset 4', 31: 'Dataset 2'}
# Running counter: {'Dataset 1': 962, 'Dataset 2': 5972, 'Dataset 3': 12214, 'Dataset 4': 12116}
# Running percentages: {'Dataset 1': '3.077021494370522%', 'Dataset 2': '19.101842374616172%', 'Dataset 3': '39.06729785056295%', 'Dataset 4': '38.75383828045036%'}
# --------------------------------------------------------------------------------
# Batch 978
# {31: 'Dataset 2', 81: 'Dataset 3', 781: 'Dataset 4', 32: 'Dataset 2', 782: 'Dataset 4', 83: 'Dataset 3', 783: 'Dataset 4', 34: 'Dataset 2', 84: 'Dataset 3', 784: 'Dataset 4', 35: 'Dataset 2', 85: 'Dataset 3', 785: 'Dataset 4', 86: 'Dataset 3'}
# Running counter: {'Dataset 1': 962, 'Dataset 2': 5981, 'Dataset 3': 12225, 'Dataset 4': 12128}
# Running percentages: {'Dataset 1': '3.073875255623722%', 'Dataset 2': '19.111068507157462%', 'Dataset 3': '39.0625%', 'Dataset 4': '38.75255623721882%'}
# --------------------------------------------------------------------------------
# Batch 979
# {86: 'Dataset 3', 786: 'Dataset 4', 87: 'Dataset 3', 38: 'Dataset 2', 88: 'Dataset 3', 89: 'Dataset 3', 789: 'Dataset 4', 40: 'Dataset 2', 90: 'Dataset 3', 790: 'Dataset 4', 91: 'Dataset 3', 791: 'Dataset 4', 2: 'Dataset 1', 92: 'Dataset 3', 792: 'Dataset 4', 3: 'Dataset 1'}
# Running counter: {'Dataset 1': 964, 'Dataset 2': 5983, 'Dataset 3': 12236, 'Dataset 4': 12145}
# Running percentages: {'Dataset 1': '3.0771195097037793%', 'Dataset 2': '19.097931562819205%', 'Dataset 3': '39.05771195097037%', 'Dataset 4': '38.767236976506645%'}
# --------------------------------------------------------------------------------
# Batch 980
# {43: 'Dataset 2', 93: 'Dataset 3', 793: 'Dataset 4', 94: 'Dataset 3', 794: 'Dataset 4', 45: 'Dataset 2', 95: 'Dataset 3', 795: 'Dataset 4', 46: 'Dataset 2', 96: 'Dataset 3', 797: 'Dataset 4', 48: 'Dataset 2', 798: 'Dataset 4', 99: 'Dataset 3', 799: 'Dataset 4', 0: 'Dataset 3'}
# Running counter: {'Dataset 1': 964, 'Dataset 2': 5990, 'Dataset 3': 12247, 'Dataset 4': 12159}
# Running percentages: {'Dataset 1': '3.0739795918367347%', 'Dataset 2': '19.10076530612245%', 'Dataset 3': '39.05293367346939%', 'Dataset 4': '38.77232142857142%'}
# --------------------------------------------------------------------------------
# Batch 981
# {0: 'Dataset 3', 1: 'Dataset 3', 801: 'Dataset 4', 2: 'Dataset 3', 803: 'Dataset 4', 804: 'Dataset 4', 5: 'Dataset 3', 805: 'Dataset 4', 6: 'Dataset 3', 7: 'Dataset 3', 807: 'Dataset 4', 8: 'Dataset 3'}
# Running counter: {'Dataset 1': 965, 'Dataset 2': 6000, 'Dataset 3': 12256, 'Dataset 4': 12171}
# Running percentages: {'Dataset 1': '3.0740316004077473%', 'Dataset 2': '19.113149847094803%', 'Dataset 3': '39.04179408766565%', 'Dataset 4': '38.771024464831804%'}
# --------------------------------------------------------------------------------
# Batch 982
# {808: 'Dataset 4', 9: 'Dataset 1', 809: 'Dataset 4', 10: 'Dataset 3', 810: 'Dataset 4', 11: 'Dataset 3', 811: 'Dataset 4', 12: 'Dataset 3', 812: 'Dataset 4', 3: 'Dataset 1', 13: 'Dataset 3', 813: 'Dataset 4', 14: 'Dataset 2'}
# Running counter: {'Dataset 1': 967, 'Dataset 2': 6005, 'Dataset 3': 12268, 'Dataset 4': 12184}
# Running percentages: {'Dataset 1': '3.077265784114053%', 'Dataset 2': '19.109597759674134%', 'Dataset 3': '39.04022403258656%', 'Dataset 4': '38.77291242362526%'}
# --------------------------------------------------------------------------------
# Batch 983
# {14: 'Dataset 3', 814: 'Dataset 4', 5: 'Dataset 1', 15: 'Dataset 3', 815: 'Dataset 4', 816: 'Dataset 4', 17: 'Dataset 3', 817: 'Dataset 4', 18: 'Dataset 3', 818: 'Dataset 4', 19: 'Dataset 2', 819: 'Dataset 4', 20: 'Dataset 2'}
# Running counter: {'Dataset 1': 968, 'Dataset 2': 6014, 'Dataset 3': 12276, 'Dataset 4': 12198}
# Running percentages: {'Dataset 1': '3.077314343845371%', 'Dataset 2': '19.118769074262463%', 'Dataset 3': '39.025940996948115%', 'Dataset 4': '38.777975584944045%'}
# --------------------------------------------------------------------------------
# Batch 984
# {20: 'Dataset 3', 820: 'Dataset 4', 21: 'Dataset 3', 2: 'Dataset 1', 22: 'Dataset 3', 822: 'Dataset 4', 3: 'Dataset 1', 23: 'Dataset 3', 823: 'Dataset 4', 4: 'Dataset 1', 24: 'Dataset 2', 25: 'Dataset 3', 825: 'Dataset 4', 26: 'Dataset 3', 826: 'Dataset 4', 27: 'Dataset 3'}
# Running counter: {'Dataset 1': 971, 'Dataset 2': 6022, 'Dataset 3': 12289, 'Dataset 4': 12206}
# Running percentages: {'Dataset 1': '3.083714430894309%', 'Dataset 2': '19.12474593495935%', 'Dataset 3': '39.027566056910565%', 'Dataset 4': '38.763973577235774%'}
# --------------------------------------------------------------------------------
# Batch 985
# {27: 'Dataset 3', 827: 'Dataset 4', 28: 'Dataset 3', 828: 'Dataset 4', 29: 'Dataset 2', 829: 'Dataset 4', 30: 'Dataset 3', 31: 'Dataset 2', 831: 'Dataset 4', 32: 'Dataset 3', 832: 'Dataset 4', 33: 'Dataset 3', 833: 'Dataset 4', 34: 'Dataset 3', 35: 'Dataset 2', 835: 'Dataset 4'}
# Running counter: {'Dataset 1': 971, 'Dataset 2': 6030, 'Dataset 3': 12303, 'Dataset 4': 12216}
# Running percentages: {'Dataset 1': '3.080583756345178%', 'Dataset 2': '19.13071065989848%', 'Dataset 3': '39.03236040609137%', 'Dataset 4': '38.756345177664976%'}
# --------------------------------------------------------------------------------
# Batch 986
# {835: 'Dataset 4', 36: 'Dataset 3', 836: 'Dataset 4', 37: 'Dataset 3', 837: 'Dataset 4', 38: 'Dataset 3', 838: 'Dataset 4', 39: 'Dataset 2', 839: 'Dataset 4', 40: 'Dataset 3', 840: 'Dataset 4', 41: 'Dataset 2', 841: 'Dataset 4', 42: 'Dataset 3'}
# Running counter: {'Dataset 1': 971, 'Dataset 2': 6041, 'Dataset 3': 12311, 'Dataset 4': 12229}
# Running percentages: {'Dataset 1': '3.0774594320486814%', 'Dataset 2': '19.14617139959432%', 'Dataset 3': '39.01812880324544%', 'Dataset 4': '38.75824036511156%'}
# --------------------------------------------------------------------------------
# Batch 987
# {42: 'Dataset 3', 842: 'Dataset 4', 43: 'Dataset 3', 843: 'Dataset 4', 44: 'Dataset 3', 844: 'Dataset 4', 45: 'Dataset 3', 845: 'Dataset 4', 46: 'Dataset 2', 846: 'Dataset 4', 847: 'Dataset 4', 48: 'Dataset 3', 848: 'Dataset 4', 49: 'Dataset 2'}
# Running counter: {'Dataset 1': 971, 'Dataset 2': 6046, 'Dataset 3': 12320, 'Dataset 4': 12247}
# Running percentages: {'Dataset 1': '3.074341438703141%', 'Dataset 2': '19.14260385005066%', 'Dataset 3': '39.00709219858156%', 'Dataset 4': '38.77596251266464%'}
# --------------------------------------------------------------------------------
# Batch 988
# {49: 'Dataset 3', 849: 'Dataset 4', 50: 'Dataset 3', 1: 'Dataset 2', 851: 'Dataset 4', 2: 'Dataset 2', 852: 'Dataset 4', 54: 'Dataset 3', 5: 'Dataset 1', 55: 'Dataset 3', 855: 'Dataset 4', 6: 'Dataset 2', 56: 'Dataset 3', 57: 'Dataset 3', 8: 'Dataset 2', 59: 'Dataset 3', 10: 'Dataset 2', 60: 'Dataset 3', 860: 'Dataset 4', 11: 'Dataset 2', 861: 'Dataset 4', 12: 'Dataset 2'}
# Running counter: {'Dataset 1': 972, 'Dataset 2': 6055, 'Dataset 3': 12334, 'Dataset 4': 12255}
# Running percentages: {'Dataset 1': '3.074392712550607%', 'Dataset 2': '19.151695344129553%', 'Dataset 3': '39.011892712550605%', 'Dataset 4': '38.762019230769226%'}
# --------------------------------------------------------------------------------
# Batch 989
# {862: 'Dataset 4', 13: 'Dataset 2', 63: 'Dataset 3', 863: 'Dataset 4', 64: 'Dataset 3', 864: 'Dataset 4', 5: 'Dataset 1', 15: 'Dataset 2', 65: 'Dataset 3', 865: 'Dataset 4', 16: 'Dataset 2', 66: 'Dataset 3', 866: 'Dataset 4', 67: 'Dataset 3', 68: 'Dataset 3', 868: 'Dataset 4', 19: 'Dataset 2', 69: 'Dataset 3', 869: 'Dataset 4', 20: 'Dataset 2'}
# Running counter: {'Dataset 1': 973, 'Dataset 2': 6063, 'Dataset 3': 12345, 'Dataset 4': 12267}
# Running percentages: {'Dataset 1': '3.074443882709808%', 'Dataset 2': '19.157608695652172%', 'Dataset 3': '39.00720424671385%', 'Dataset 4': '38.760743174924166%'}
# --------------------------------------------------------------------------------
# Batch 990
# {70: 'Dataset 3', 870: 'Dataset 4', 71: 'Dataset 3', 871: 'Dataset 4', 2: 'Dataset 1', 872: 'Dataset 4', 23: 'Dataset 2', 873: 'Dataset 4', 874: 'Dataset 4', 75: 'Dataset 3', 875: 'Dataset 4', 26: 'Dataset 2', 76: 'Dataset 3', 876: 'Dataset 4', 877: 'Dataset 4', 8: 'Dataset 1', 878: 'Dataset 4'}
# Running counter: {'Dataset 1': 976, 'Dataset 2': 6065, 'Dataset 3': 12354, 'Dataset 4': 12285}
# Running percentages: {'Dataset 1': '3.080808080808081%', 'Dataset 2': '19.144570707070706%', 'Dataset 3': '38.99621212121212%', 'Dataset 4': '38.778409090909086%'}
# --------------------------------------------------------------------------------
# Batch 991
# {29: 'Dataset 2', 879: 'Dataset 4', 880: 'Dataset 4', 31: 'Dataset 2', 81: 'Dataset 3', 881: 'Dataset 4', 82: 'Dataset 3', 882: 'Dataset 4', 33: 'Dataset 2', 83: 'Dataset 3', 883: 'Dataset 4', 34: 'Dataset 2', 884: 'Dataset 4', 35: 'Dataset 2', 85: 'Dataset 3'}
# Running counter: {'Dataset 1': 976, 'Dataset 2': 6073, 'Dataset 3': 12365, 'Dataset 4': 12298}
# Running percentages: {'Dataset 1': '3.077699293642785%', 'Dataset 2': '19.15047931382442%', 'Dataset 3': '38.99154894046418%', 'Dataset 4': '38.780272452068616%'}
# --------------------------------------------------------------------------------
# Batch 992
# {885: 'Dataset 4', 86: 'Dataset 3', 886: 'Dataset 4', 37: 'Dataset 2', 87: 'Dataset 3', 887: 'Dataset 4', 38: 'Dataset 2', 88: 'Dataset 3', 888: 'Dataset 4', 39: 'Dataset 2', 89: 'Dataset 3', 40: 'Dataset 2', 90: 'Dataset 3', 890: 'Dataset 4', 41: 'Dataset 2', 91: 'Dataset 3', 42: 'Dataset 2', 92: 'Dataset 3', 892: 'Dataset 4', 43: 'Dataset 2', 93: 'Dataset 3'}
# Running counter: {'Dataset 1': 976, 'Dataset 2': 6081, 'Dataset 3': 12381, 'Dataset 4': 12306}
# Running percentages: {'Dataset 1': '3.0745967741935485%', 'Dataset 2': '19.156376008064516%', 'Dataset 3': '39.00264616935484%', 'Dataset 4': '38.766381048387096%'}
# --------------------------------------------------------------------------------
# Batch 993
# {893: 'Dataset 4', 94: 'Dataset 3', 894: 'Dataset 4', 45: 'Dataset 2', 46: 'Dataset 2', 96: 'Dataset 3', 896: 'Dataset 4', 47: 'Dataset 2', 98: 'Dataset 3', 898: 'Dataset 4', 99: 'Dataset 3', 0: 'Dataset 3', 1: 'Dataset 3', 901: 'Dataset 4', 2: 'Dataset 3', 902: 'Dataset 4', 3: 'Dataset 3'}
# Running counter: {'Dataset 1': 976, 'Dataset 2': 6088, 'Dataset 3': 12394, 'Dataset 4': 12318}
# Running percentages: {'Dataset 1': '3.0715005035246725%', 'Dataset 2': '19.159113796576033%', 'Dataset 3': '39.004279959718026%', 'Dataset 4': '38.76510574018127%'}
# --------------------------------------------------------------------------------
# Batch 994
# {903: 'Dataset 4', 4: 'Dataset 3', 5: 'Dataset 3', 905: 'Dataset 4', 6: 'Dataset 3', 906: 'Dataset 4', 7: 'Dataset 3', 8: 'Dataset 3', 9: 'Dataset 2', 10: 'Dataset 3', 1: 'Dataset 1', 11: 'Dataset 3', 911: 'Dataset 4'}
# Running counter: {'Dataset 1': 977, 'Dataset 2': 6094, 'Dataset 3': 12411, 'Dataset 4': 12326}
# Running percentages: {'Dataset 1': '3.0715543259557347%', 'Dataset 2': '19.15870221327968%', 'Dataset 3': '39.01848591549296%', 'Dataset 4': '38.75125754527163%'}
# --------------------------------------------------------------------------------
# Batch 995
# {12: 'Dataset 3', 912: 'Dataset 4', 13: 'Dataset 3', 913: 'Dataset 4', 14: 'Dataset 3', 914: 'Dataset 4', 15: 'Dataset 3', 915: 'Dataset 4', 16: 'Dataset 2', 916: 'Dataset 4', 17: 'Dataset 3'}
# Running counter: {'Dataset 1': 977, 'Dataset 2': 6100, 'Dataset 3': 12424, 'Dataset 4': 12339}
# Running percentages: {'Dataset 1': '3.068467336683417%', 'Dataset 2': '19.158291457286435%', 'Dataset 3': '39.02010050251256%', 'Dataset 4': '38.75314070351759%'}
# --------------------------------------------------------------------------------
# Batch 996
# {18: 'Dataset 3', 918: 'Dataset 4', 19: 'Dataset 3', 919: 'Dataset 4', 20: 'Dataset 3', 21: 'Dataset 3', 22: 'Dataset 3', 922: 'Dataset 4', 23: 'Dataset 3', 923: 'Dataset 4', 4: 'Dataset 1'}
# Running counter: {'Dataset 1': 978, 'Dataset 2': 6107, 'Dataset 3': 12442, 'Dataset 4': 12345}
# Running percentages: {'Dataset 1': '3.0685240963855422%', 'Dataset 2': '19.161019076305223%', 'Dataset 3': '39.03739959839358%', 'Dataset 4': '38.73305722891566%'}
# --------------------------------------------------------------------------------
# Batch 997
# {24: 'Dataset 3', 924: 'Dataset 4', 25: 'Dataset 3', 925: 'Dataset 4', 6: 'Dataset 1', 26: 'Dataset 3', 27: 'Dataset 2', 927: 'Dataset 4', 28: 'Dataset 2', 928: 'Dataset 4', 29: 'Dataset 3', 929: 'Dataset 4', 30: 'Dataset 3', 1: 'Dataset 1', 31: 'Dataset 3', 932: 'Dataset 4', 33: 'Dataset 3'}
# Running counter: {'Dataset 1': 980, 'Dataset 2': 6116, 'Dataset 3': 12450, 'Dataset 4': 12358}
# Running percentages: {'Dataset 1': '3.071715145436309%', 'Dataset 2': '19.17001003009027%', 'Dataset 3': '39.023319959879636%', 'Dataset 4': '38.73495486459378%'}
# --------------------------------------------------------------------------------
# Batch 998
# {33: 'Dataset 3', 933: 'Dataset 4', 34: 'Dataset 3', 934: 'Dataset 4', 35: 'Dataset 3', 935: 'Dataset 4', 936: 'Dataset 4', 37: 'Dataset 3', 937: 'Dataset 4', 38: 'Dataset 3', 938: 'Dataset 4', 9: 'Dataset 1', 39: 'Dataset 3', 939: 'Dataset 4', 40: 'Dataset 3', 41: 'Dataset 2'}
# Running counter: {'Dataset 1': 981, 'Dataset 2': 6121, 'Dataset 3': 12464, 'Dataset 4': 12370}
# Running percentages: {'Dataset 1': '3.0717685370741483%', 'Dataset 2': '19.166457915831664%', 'Dataset 3': '39.02805611222445%', 'Dataset 4': '38.73371743486974%'}
# --------------------------------------------------------------------------------
# Batch 999
# {41: 'Dataset 3', 941: 'Dataset 4', 42: 'Dataset 3', 942: 'Dataset 4', 943: 'Dataset 4', 44: 'Dataset 3', 944: 'Dataset 4', 45: 'Dataset 3', 945: 'Dataset 4', 6: 'Dataset 1', 46: 'Dataset 3', 946: 'Dataset 4', 47: 'Dataset 3', 48: 'Dataset 3', 948: 'Dataset 4', 49: 'Dataset 3'}
# Running counter: {'Dataset 1': 982, 'Dataset 2': 6125, 'Dataset 3': 12478, 'Dataset 4': 12383}
# Running percentages: {'Dataset 1': '3.071821821821822%', 'Dataset 2': '19.159784784784783%', 'Dataset 3': '39.03278278278278%', 'Dataset 4': '38.73561061061061%'}
# --------------------------------------------------------------------------------
# Batch 1000
# {949: 'Dataset 4', 0: 'Dataset 2', 950: 'Dataset 4', 51: 'Dataset 3', 2: 'Dataset 1', 52: 'Dataset 3', 3: 'Dataset 2', 53: 'Dataset 3', 953: 'Dataset 4', 4: 'Dataset 1', 5: 'Dataset 2', 55: 'Dataset 3', 955: 'Dataset 4', 56: 'Dataset 3', 956: 'Dataset 4', 57: 'Dataset 3', 957: 'Dataset 4', 8: 'Dataset 2', 58: 'Dataset 3', 958: 'Dataset 4'}
# Running counter: {'Dataset 1': 985, 'Dataset 2': 6129, 'Dataset 3': 12494, 'Dataset 4': 12392}
# Running percentages: {'Dataset 1': '3.078125%', 'Dataset 2': '19.153125%', 'Dataset 3': '39.04375%', 'Dataset 4': '38.725%'}
# --------------------------------------------------------------------------------

# %% [markdown]
# Thoughts:
# - There's an uneven number of samples from each dataset for all batches
#   - The larger datasets dominate in terms of number of entries for all batches

# %% [markdown]
# ### Strategy 2

# %%
def symmetric_extreme_swap(lst):
    """
    Swap the smallest element with the largest, the second smallest with the
    second largest, and so on.

    Args:
        lst (list): A list of numbers.

    Returns:
        list: A new list with the specified elements swapped.
    """
    lst_copy = lst.copy()
    sorted_indices = sorted(range(len(lst)), key=lambda i: lst[i])
    n = len(lst)

    for i in range(n // 2):
        small_idx = sorted_indices[i]
        large_idx = sorted_indices[-(i + 1)]
        lst_copy[small_idx], lst_copy[large_idx] = (
            lst_copy[large_idx],
            lst_copy[small_idx],
        )

    return lst_copy

# %% [markdown]
# Use `RandomYield` to increase the probability of sampling smaller datasets.

# %%
from gluonts.itertools import RandomYield, Cyclic

dataset_lengths = [len(list(dataset)) for dataset in datasets]
inverse_lengths = np.array([1.0 / length for length in dataset_lengths])
probabilities = (inverse_lengths / inverse_lengths.sum()).tolist()

print(probabilities)

random_yield = RandomYield(
    iterables=[Cyclic(dataset) for dataset in datasets],
)
# Out:
# [0.7633587786259542, 0.15267175572519084, 0.07633587786259542, 0.007633587786259542]

# %% [markdown]
# Create a dataloader.

# %%
data_loader = TrainDataLoader(
    dataset=random_yield,
    batch_size=batch_size,
    stack_fn=batchify,
    transform=mask_unobserved + splitter,
    num_batches_per_epoch=num_batches_per_epoch,
    shuffle_buffer_length=1024,
)

# %% [markdown]
# Count how many samples belong to each dataset in each batch.
# - Each batch is a dict of key-value pairs:
#   - Each key is a different feature e.g. "start" or "past_target"
#   - Each value is a list of `batch_size` elements

# %%
from collections import Counter

counter = Counter()

for i, batch in enumerate(data_loader):
    print(f"Batch {i + 1}")

    series_numbers = batch["series_number"]
    sources = batch["source"]

    # See which time series where used for this batch
    print(
        {
            series_number: source
            for series_number, source in zip(series_numbers, sources)
        }
    )

    # Update counter with number of entries from each source in the batch
    counter.update(sources)
    print(f"Running counter: {dict(sorted(counter.items()))}")

    # Count the total number of entries in the batch
    total = sum(counter.values())

    # Convert each count to percentages
    percentages = {k: f"{str((v / total) * 100)}%" for k, v in counter.items()}
    print(f"Running percentages: {dict(sorted(percentages.items()))}")
    print("-" * 80)
# Out:
# Batch 1
# {179: 'Dataset 4', 41: 'Dataset 2', 137: 'Dataset 4', 83: 'Dataset 3', 11: 'Dataset 2', 87: 'Dataset 3', 63: 'Dataset 3', 15: 'Dataset 2', 8: 'Dataset 1', 69: 'Dataset 4', 85: 'Dataset 3', 7: 'Dataset 3'}
# Running counter: {'Dataset 1': 1, 'Dataset 2': 7, 'Dataset 3': 14, 'Dataset 4': 10}
# Running percentages: {'Dataset 1': '3.125%', 'Dataset 2': '21.875%', 'Dataset 3': '43.75%', 'Dataset 4': '31.25%'}
# --------------------------------------------------------------------------------
# Batch 2
# {41: 'Dataset 2', 24: 'Dataset 2', 224: 'Dataset 4', 73: 'Dataset 3', 153: 'Dataset 4', 8: 'Dataset 4', 1: 'Dataset 1', 52: 'Dataset 3', 194: 'Dataset 4', 45: 'Dataset 3', 43: 'Dataset 3', 59: 'Dataset 3', 159: 'Dataset 4', 241: 'Dataset 4', 86: 'Dataset 3'}
# Running counter: {'Dataset 1': 2, 'Dataset 2': 10, 'Dataset 3': 27, 'Dataset 4': 25}
# Running percentages: {'Dataset 1': '3.125%', 'Dataset 2': '15.625%', 'Dataset 3': '42.1875%', 'Dataset 4': '39.0625%'}
# --------------------------------------------------------------------------------
# Batch 3
# {86: 'Dataset 3', 2: 'Dataset 3', 20: 'Dataset 2', 93: 'Dataset 3', 223: 'Dataset 4', 74: 'Dataset 4', 33: 'Dataset 2', 257: 'Dataset 4', 103: 'Dataset 4', 132: 'Dataset 4', 5: 'Dataset 1', 76: 'Dataset 4', 128: 'Dataset 4'}
# Running counter: {'Dataset 1': 3, 'Dataset 2': 13, 'Dataset 3': 32, 'Dataset 4': 48}
# Running percentages: {'Dataset 1': '3.125%', 'Dataset 2': '13.541666666666666%', 'Dataset 3': '33.33333333333333%', 'Dataset 4': '50.0%'}
# --------------------------------------------------------------------------------
# Batch 4
# {128: 'Dataset 4', 48: 'Dataset 3', 52: 'Dataset 3', 21: 'Dataset 3', 27: 'Dataset 3', 32: 'Dataset 2', 265: 'Dataset 4', 185: 'Dataset 4', 9: 'Dataset 3', 5: 'Dataset 1', 316: 'Dataset 4', 276: 'Dataset 4'}
# Running counter: {'Dataset 1': 5, 'Dataset 2': 17, 'Dataset 3': 47, 'Dataset 4': 59}
# Running percentages: {'Dataset 1': '3.90625%', 'Dataset 2': '13.28125%', 'Dataset 3': '36.71875%', 'Dataset 4': '46.09375%'}
# --------------------------------------------------------------------------------
# Batch 5
# {276: 'Dataset 4', 9: 'Dataset 1', 26: 'Dataset 2', 2: 'Dataset 2', 45: 'Dataset 3', 7: 'Dataset 1', 35: 'Dataset 3', 149: 'Dataset 4', 8: 'Dataset 2', 30: 'Dataset 4', 49: 'Dataset 2', 37: 'Dataset 3', 12: 'Dataset 2', 259: 'Dataset 4', 289: 'Dataset 4'}
# Running counter: {'Dataset 1': 7, 'Dataset 2': 28, 'Dataset 3': 53, 'Dataset 4': 72}
# Running percentages: {'Dataset 1': '4.375%', 'Dataset 2': '17.5%', 'Dataset 3': '33.125%', 'Dataset 4': '45.0%'}
# --------------------------------------------------------------------------------
# Batch 6
# {289: 'Dataset 4', 41: 'Dataset 2', 5: 'Dataset 2', 37: 'Dataset 2', 1: 'Dataset 1', 8: 'Dataset 3', 16: 'Dataset 2', 79: 'Dataset 3', 6: 'Dataset 1', 107: 'Dataset 4', 136: 'Dataset 4', 17: 'Dataset 2', 47: 'Dataset 4', 21: 'Dataset 2', 20: 'Dataset 3', 18: 'Dataset 3'}
# Running counter: {'Dataset 1': 9, 'Dataset 2': 39, 'Dataset 3': 61, 'Dataset 4': 83}
# Running percentages: {'Dataset 1': '4.6875%', 'Dataset 2': '20.3125%', 'Dataset 3': '31.770833333333332%', 'Dataset 4': '43.22916666666667%'}
# --------------------------------------------------------------------------------
# Batch 7
# {142: 'Dataset 4', 293: 'Dataset 4', 288: 'Dataset 4', 0: 'Dataset 1', 45: 'Dataset 4', 16: 'Dataset 2', 98: 'Dataset 3', 20: 'Dataset 4', 6: 'Dataset 2', 55: 'Dataset 4', 18: 'Dataset 2', 8: 'Dataset 3', 2: 'Dataset 3'}
# Running counter: {'Dataset 1': 11, 'Dataset 2': 46, 'Dataset 3': 71, 'Dataset 4': 96}
# Running percentages: {'Dataset 1': '4.910714285714286%', 'Dataset 2': '20.535714285714285%', 'Dataset 3': '31.69642857142857%', 'Dataset 4': '42.857142857142854%'}
# --------------------------------------------------------------------------------
# Batch 8
# {2: 'Dataset 3', 49: 'Dataset 2', 216: 'Dataset 4', 0: 'Dataset 1', 52: 'Dataset 4', 42: 'Dataset 3', 43: 'Dataset 4', 14: 'Dataset 2', 3: 'Dataset 2', 252: 'Dataset 4', 9: 'Dataset 1', 75: 'Dataset 4', 118: 'Dataset 4', 28: 'Dataset 2'}
# Running counter: {'Dataset 1': 13, 'Dataset 2': 53, 'Dataset 3': 79, 'Dataset 4': 111}
# Running percentages: {'Dataset 1': '5.078125%', 'Dataset 2': '20.703125%', 'Dataset 3': '30.859375%', 'Dataset 4': '43.359375%'}
# --------------------------------------------------------------------------------
# Batch 9
# {49: 'Dataset 2', 220: 'Dataset 4', 6: 'Dataset 2', 261: 'Dataset 4', 18: 'Dataset 3', 28: 'Dataset 2', 297: 'Dataset 4', 57: 'Dataset 3', 1: 'Dataset 2'}
# Running counter: {'Dataset 1': 13, 'Dataset 2': 61, 'Dataset 3': 89, 'Dataset 4': 125}
# Running percentages: {'Dataset 1': '4.513888888888888%', 'Dataset 2': '21.180555555555554%', 'Dataset 3': '30.90277777777778%', 'Dataset 4': '43.40277777777778%'}
# --------------------------------------------------------------------------------
# Batch 10
# {197: 'Dataset 4', 6: 'Dataset 1', 35: 'Dataset 2', 44: 'Dataset 2', 2: 'Dataset 1', 9: 'Dataset 1', 30: 'Dataset 2', 270: 'Dataset 4', 37: 'Dataset 2', 195: 'Dataset 4', 57: 'Dataset 3', 46: 'Dataset 2', 0: 'Dataset 1'}
# Running counter: {'Dataset 1': 17, 'Dataset 2': 73, 'Dataset 3': 99, 'Dataset 4': 131}
# Running percentages: {'Dataset 1': '5.3125%', 'Dataset 2': '22.8125%', 'Dataset 3': '30.9375%', 'Dataset 4': '40.9375%'}
# --------------------------------------------------------------------------------
# Batch 11
# {73: 'Dataset 3', 162: 'Dataset 4', 102: 'Dataset 4', 62: 'Dataset 3', 82: 'Dataset 3', 8: 'Dataset 1', 338: 'Dataset 4', 15: 'Dataset 4', 67: 'Dataset 3', 13: 'Dataset 3', 5: 'Dataset 1', 80: 'Dataset 3'}
# Running counter: {'Dataset 1': 19, 'Dataset 2': 73, 'Dataset 3': 114, 'Dataset 4': 146}
# Running percentages: {'Dataset 1': '5.3977272727272725%', 'Dataset 2': '20.738636363636363%', 'Dataset 3': '32.38636363636363%', 'Dataset 4': '41.47727272727273%'}
# --------------------------------------------------------------------------------
# Batch 12
# {80: 'Dataset 3', 25: 'Dataset 2', 4: 'Dataset 3', 13: 'Dataset 3', 246: 'Dataset 4', 42: 'Dataset 2', 215: 'Dataset 4', 67: 'Dataset 4', 54: 'Dataset 3', 5: 'Dataset 1', 2: 'Dataset 2', 12: 'Dataset 3', 296: 'Dataset 4'}
# Running counter: {'Dataset 1': 20, 'Dataset 2': 77, 'Dataset 3': 127, 'Dataset 4': 160}
# Running percentages: {'Dataset 1': '5.208333333333334%', 'Dataset 2': '20.052083333333336%', 'Dataset 3': '33.07291666666667%', 'Dataset 4': '41.66666666666667%'}
# --------------------------------------------------------------------------------
# Batch 13
# {84: 'Dataset 4', 90: 'Dataset 3', 23: 'Dataset 3', 42: 'Dataset 2', 6: 'Dataset 3', 278: 'Dataset 4', 243: 'Dataset 4', 31: 'Dataset 2', 63: 'Dataset 3', 202: 'Dataset 4', 15: 'Dataset 2'}
# Running counter: {'Dataset 1': 20, 'Dataset 2': 85, 'Dataset 3': 138, 'Dataset 4': 173}
# Running percentages: {'Dataset 1': '4.807692307692308%', 'Dataset 2': '20.432692307692307%', 'Dataset 3': '33.17307692307692%', 'Dataset 4': '41.58653846153847%'}
# --------------------------------------------------------------------------------
# Batch 14
# {42: 'Dataset 2', 80: 'Dataset 3', 64: 'Dataset 3', 253: 'Dataset 4', 18: 'Dataset 4', 56: 'Dataset 3', 33: 'Dataset 2', 35: 'Dataset 3', 7: 'Dataset 2', 346: 'Dataset 4', 10: 'Dataset 2', 186: 'Dataset 4', 65: 'Dataset 3', 19: 'Dataset 2', 32: 'Dataset 3'}
# Running counter: {'Dataset 1': 20, 'Dataset 2': 95, 'Dataset 3': 150, 'Dataset 4': 183}
# Running percentages: {'Dataset 1': '4.464285714285714%', 'Dataset 2': '21.205357142857142%', 'Dataset 3': '33.482142857142854%', 'Dataset 4': '40.848214285714285%'}
# --------------------------------------------------------------------------------
# Batch 15
# {32: 'Dataset 3', 99: 'Dataset 3', 178: 'Dataset 4', 70: 'Dataset 3', 34: 'Dataset 3', 327: 'Dataset 4', 33: 'Dataset 3', 29: 'Dataset 3', 240: 'Dataset 4', 43: 'Dataset 3'}
# Running counter: {'Dataset 1': 20, 'Dataset 2': 95, 'Dataset 3': 170, 'Dataset 4': 195}
# Running percentages: {'Dataset 1': '4.166666666666666%', 'Dataset 2': '19.791666666666664%', 'Dataset 3': '35.41666666666667%', 'Dataset 4': '40.625%'}
# --------------------------------------------------------------------------------
# Batch 16
# {43: 'Dataset 3', 7: 'Dataset 3', 41: 'Dataset 3', 254: 'Dataset 4', 21: 'Dataset 2', 77: 'Dataset 3', 3: 'Dataset 1', 60: 'Dataset 3', 39: 'Dataset 2', 127: 'Dataset 4'}
# Running counter: {'Dataset 1': 22, 'Dataset 2': 100, 'Dataset 3': 187, 'Dataset 4': 203}
# Running percentages: {'Dataset 1': '4.296875%', 'Dataset 2': '19.53125%', 'Dataset 3': '36.5234375%', 'Dataset 4': '39.6484375%'}
# --------------------------------------------------------------------------------
# Batch 17
# {127: 'Dataset 4', 1: 'Dataset 4', 28: 'Dataset 3', 26: 'Dataset 3', 87: 'Dataset 3', 51: 'Dataset 3', 311: 'Dataset 4', 343: 'Dataset 4', 182: 'Dataset 4', 15: 'Dataset 2'}
# Running counter: {'Dataset 1': 23, 'Dataset 2': 102, 'Dataset 3': 202, 'Dataset 4': 217}
# Running percentages: {'Dataset 1': '4.227941176470589%', 'Dataset 2': '18.75%', 'Dataset 3': '37.13235294117647%', 'Dataset 4': '39.88970588235294%'}
# --------------------------------------------------------------------------------
# Batch 18
# {37: 'Dataset 2', 43: 'Dataset 3', 8: 'Dataset 2', 40: 'Dataset 2', 222: 'Dataset 4', 198: 'Dataset 4', 5: 'Dataset 1', 4: 'Dataset 2', 279: 'Dataset 4', 321: 'Dataset 4', 357: 'Dataset 4', 69: 'Dataset 3', 26: 'Dataset 2'}
# Running counter: {'Dataset 1': 24, 'Dataset 2': 111, 'Dataset 3': 207, 'Dataset 4': 234}
# Running percentages: {'Dataset 1': '4.166666666666666%', 'Dataset 2': '19.270833333333336%', 'Dataset 3': '35.9375%', 'Dataset 4': '40.625%'}
# --------------------------------------------------------------------------------
# Batch 19
# {26: 'Dataset 2', 5: 'Dataset 2', 312: 'Dataset 4', 209: 'Dataset 4', 302: 'Dataset 4', 76: 'Dataset 3', 22: 'Dataset 2', 9: 'Dataset 3', 2: 'Dataset 2', 281: 'Dataset 4', 193: 'Dataset 4', 21: 'Dataset 2', 57: 'Dataset 3'}
# Running counter: {'Dataset 1': 24, 'Dataset 2': 116, 'Dataset 3': 216, 'Dataset 4': 252}
# Running percentages: {'Dataset 1': '3.9473684210526314%', 'Dataset 2': '19.078947368421055%', 'Dataset 3': '35.526315789473685%', 'Dataset 4': '41.44736842105263%'}
# --------------------------------------------------------------------------------
# Batch 20
# {57: 'Dataset 3', 87: 'Dataset 3', 31: 'Dataset 2', 2: 'Dataset 4', 117: 'Dataset 4', 99: 'Dataset 3', 309: 'Dataset 4', 5: 'Dataset 1', 355: 'Dataset 4', 59: 'Dataset 3', 81: 'Dataset 3', 191: 'Dataset 4'}
# Running counter: {'Dataset 1': 25, 'Dataset 2': 119, 'Dataset 3': 228, 'Dataset 4': 268}
# Running percentages: {'Dataset 1': '3.90625%', 'Dataset 2': '18.59375%', 'Dataset 3': '35.625%', 'Dataset 4': '41.875%'}
# --------------------------------------------------------------------------------
# Batch 21
# {353: 'Dataset 4', 9: 'Dataset 1', 34: 'Dataset 2', 19: 'Dataset 3', 83: 'Dataset 3', 39: 'Dataset 3', 89: 'Dataset 4', 35: 'Dataset 2', 282: 'Dataset 4', 13: 'Dataset 3', 192: 'Dataset 4', 54: 'Dataset 4', 60: 'Dataset 3'}
# Running counter: {'Dataset 1': 26, 'Dataset 2': 122, 'Dataset 3': 242, 'Dataset 4': 282}
# Running percentages: {'Dataset 1': '3.869047619047619%', 'Dataset 2': '18.154761904761905%', 'Dataset 3': '36.01190476190476%', 'Dataset 4': '41.964285714285715%'}
# --------------------------------------------------------------------------------
# Batch 22
# {12: 'Dataset 2', 86: 'Dataset 3', 25: 'Dataset 3', 337: 'Dataset 4', 0: 'Dataset 1', 150: 'Dataset 4', 334: 'Dataset 4', 255: 'Dataset 4', 46: 'Dataset 2', 28: 'Dataset 3', 9: 'Dataset 1', 14: 'Dataset 3', 352: 'Dataset 4'}
# Running counter: {'Dataset 1': 28, 'Dataset 2': 124, 'Dataset 3': 259, 'Dataset 4': 293}
# Running percentages: {'Dataset 1': '3.977272727272727%', 'Dataset 2': '17.613636363636363%', 'Dataset 3': '36.78977272727273%', 'Dataset 4': '41.61931818181818%'}
# --------------------------------------------------------------------------------
# Batch 23
# {352: 'Dataset 4', 3: 'Dataset 1', 91: 'Dataset 3', 237: 'Dataset 4', 104: 'Dataset 4', 383: 'Dataset 4', 27: 'Dataset 2', 29: 'Dataset 2', 18: 'Dataset 2', 74: 'Dataset 3', 151: 'Dataset 4', 68: 'Dataset 4', 6: 'Dataset 2', 226: 'Dataset 4', 51: 'Dataset 3', 248: 'Dataset 4'}
# Running counter: {'Dataset 1': 29, 'Dataset 2': 129, 'Dataset 3': 267, 'Dataset 4': 311}
# Running percentages: {'Dataset 1': '3.940217391304348%', 'Dataset 2': '17.527173913043477%', 'Dataset 3': '36.27717391304348%', 'Dataset 4': '42.255434782608695%'}
# --------------------------------------------------------------------------------
# Batch 24
# {248: 'Dataset 4', 42: 'Dataset 2', 84: 'Dataset 3', 22: 'Dataset 3', 382: 'Dataset 4', 92: 'Dataset 3', 9: 'Dataset 3', 120: 'Dataset 4', 71: 'Dataset 3', 25: 'Dataset 2', 267: 'Dataset 4'}
# Running counter: {'Dataset 1': 29, 'Dataset 2': 133, 'Dataset 3': 284, 'Dataset 4': 322}
# Running percentages: {'Dataset 1': '3.7760416666666665%', 'Dataset 2': '17.317708333333336%', 'Dataset 3': '36.97916666666667%', 'Dataset 4': '41.92708333333333%'}
# --------------------------------------------------------------------------------
# Batch 25
# {86: 'Dataset 3', 115: 'Dataset 4', 225: 'Dataset 4', 17: 'Dataset 2', 72: 'Dataset 3', 20: 'Dataset 2', 14: 'Dataset 2', 64: 'Dataset 3', 74: 'Dataset 3', 5: 'Dataset 3'}
# Running counter: {'Dataset 1': 29, 'Dataset 2': 140, 'Dataset 3': 304, 'Dataset 4': 327}
# Running percentages: {'Dataset 1': '3.6249999999999996%', 'Dataset 2': '17.5%', 'Dataset 3': '38.0%', 'Dataset 4': '40.875%'}
# --------------------------------------------------------------------------------
# Batch 26
# {5: 'Dataset 3', 22: 'Dataset 2', 83: 'Dataset 3', 7: 'Dataset 2', 44: 'Dataset 3', 18: 'Dataset 3', 250: 'Dataset 4', 84: 'Dataset 3', 3: 'Dataset 3', 85: 'Dataset 3', 29: 'Dataset 3', 306: 'Dataset 4', 48: 'Dataset 2', 40: 'Dataset 3'}
# Running counter: {'Dataset 1': 29, 'Dataset 2': 145, 'Dataset 3': 324, 'Dataset 4': 334}
# Running percentages: {'Dataset 1': '3.4855769230769234%', 'Dataset 2': '17.427884615384613%', 'Dataset 3': '38.94230769230769%', 'Dataset 4': '40.144230769230774%'}
# --------------------------------------------------------------------------------
# Batch 27
# {19: 'Dataset 3', 5: 'Dataset 2', 40: 'Dataset 2', 390: 'Dataset 4', 24: 'Dataset 3', 372: 'Dataset 4', 10: 'Dataset 3', 319: 'Dataset 4', 332: 'Dataset 4', 401: 'Dataset 4', 260: 'Dataset 4', 25: 'Dataset 2', 307: 'Dataset 4', 32: 'Dataset 2', 51: 'Dataset 3'}
# Running counter: {'Dataset 1': 29, 'Dataset 2': 151, 'Dataset 3': 330, 'Dataset 4': 354}
# Running percentages: {'Dataset 1': '3.356481481481482%', 'Dataset 2': '17.47685185185185%', 'Dataset 3': '38.19444444444444%', 'Dataset 4': '40.97222222222222%'}
# --------------------------------------------------------------------------------
# Batch 28
# {0: 'Dataset 3', 44: 'Dataset 2', 47: 'Dataset 2', 38: 'Dataset 3', 331: 'Dataset 4', 388: 'Dataset 4', 41: 'Dataset 3', 31: 'Dataset 3', 22: 'Dataset 2', 69: 'Dataset 3', 96: 'Dataset 4', 211: 'Dataset 4'}
# Running counter: {'Dataset 1': 29, 'Dataset 2': 156, 'Dataset 3': 350, 'Dataset 4': 361}
# Running percentages: {'Dataset 1': '3.2366071428571432%', 'Dataset 2': '17.410714285714285%', 'Dataset 3': '39.0625%', 'Dataset 4': '40.29017857142857%'}
# --------------------------------------------------------------------------------
# Batch 29
# {211: 'Dataset 4', 8: 'Dataset 2', 77: 'Dataset 3', 314: 'Dataset 4', 48: 'Dataset 3', 55: 'Dataset 3', 168: 'Dataset 4', 366: 'Dataset 4', 22: 'Dataset 4', 152: 'Dataset 4', 29: 'Dataset 2', 19: 'Dataset 3'}
# Running counter: {'Dataset 1': 31, 'Dataset 2': 158, 'Dataset 3': 360, 'Dataset 4': 379}
# Running percentages: {'Dataset 1': '3.34051724137931%', 'Dataset 2': '17.025862068965516%', 'Dataset 3': '38.793103448275865%', 'Dataset 4': '40.84051724137931%'}
# --------------------------------------------------------------------------------
# Batch 30
# {19: 'Dataset 3', 54: 'Dataset 3', 20: 'Dataset 2', 62: 'Dataset 3', 11: 'Dataset 3', 125: 'Dataset 4', 22: 'Dataset 2', 8: 'Dataset 3', 73: 'Dataset 3', 122: 'Dataset 4'}
# Running counter: {'Dataset 1': 31, 'Dataset 2': 161, 'Dataset 3': 384, 'Dataset 4': 384}
# Running percentages: {'Dataset 1': '3.229166666666667%', 'Dataset 2': '16.770833333333332%', 'Dataset 3': '40.0%', 'Dataset 4': '40.0%'}
# --------------------------------------------------------------------------------
# Batch 31
# {3: 'Dataset 2', 65: 'Dataset 3', 284: 'Dataset 4', 58: 'Dataset 3', 236: 'Dataset 4', 64: 'Dataset 3', 147: 'Dataset 4', 73: 'Dataset 4', 315: 'Dataset 4'}
# Running counter: {'Dataset 1': 31, 'Dataset 2': 164, 'Dataset 3': 396, 'Dataset 4': 401}
# Running percentages: {'Dataset 1': '3.125%', 'Dataset 2': '16.532258064516128%', 'Dataset 3': '39.91935483870967%', 'Dataset 4': '40.42338709677419%'}
# --------------------------------------------------------------------------------
# Batch 32
# {315: 'Dataset 4', 0: 'Dataset 3', 294: 'Dataset 4', 34: 'Dataset 3', 196: 'Dataset 4', 2: 'Dataset 2', 1: 'Dataset 2', 380: 'Dataset 4', 17: 'Dataset 3', 57: 'Dataset 4', 373: 'Dataset 4'}
# Running counter: {'Dataset 1': 33, 'Dataset 2': 166, 'Dataset 3': 408, 'Dataset 4': 417}
# Running percentages: {'Dataset 1': '3.22265625%', 'Dataset 2': '16.2109375%', 'Dataset 3': '39.84375%', 'Dataset 4': '40.72265625%'}
# --------------------------------------------------------------------------------
# Batch 33
# {373: 'Dataset 4', 6: 'Dataset 2', 20: 'Dataset 3', 84: 'Dataset 3', 72: 'Dataset 4', 93: 'Dataset 4', 36: 'Dataset 3', 310: 'Dataset 4', 143: 'Dataset 4', 37: 'Dataset 3', 47: 'Dataset 2', 74: 'Dataset 3'}
# Running counter: {'Dataset 1': 33, 'Dataset 2': 170, 'Dataset 3': 422, 'Dataset 4': 431}
# Running percentages: {'Dataset 1': '3.125%', 'Dataset 2': '16.098484848484848%', 'Dataset 3': '39.96212121212121%', 'Dataset 4': '40.81439393939394%'}
# --------------------------------------------------------------------------------
# Batch 34
# {156: 'Dataset 4', 48: 'Dataset 3', 9: 'Dataset 4', 7: 'Dataset 1', 286: 'Dataset 4', 148: 'Dataset 4', 45: 'Dataset 2', 27: 'Dataset 3', 378: 'Dataset 4', 11: 'Dataset 2'}
# Running counter: {'Dataset 1': 34, 'Dataset 2': 174, 'Dataset 3': 425, 'Dataset 4': 455}
# Running percentages: {'Dataset 1': '3.125%', 'Dataset 2': '15.992647058823529%', 'Dataset 3': '39.0625%', 'Dataset 4': '41.81985294117647%'}
# --------------------------------------------------------------------------------
# Batch 35
# {11: 'Dataset 2', 37: 'Dataset 3', 59: 'Dataset 4', 116: 'Dataset 4', 81: 'Dataset 4', 135: 'Dataset 4', 17: 'Dataset 2', 181: 'Dataset 4', 180: 'Dataset 4'}
# Running counter: {'Dataset 1': 34, 'Dataset 2': 179, 'Dataset 3': 428, 'Dataset 4': 479}
# Running percentages: {'Dataset 1': '3.0357142857142856%', 'Dataset 2': '15.982142857142856%', 'Dataset 3': '38.21428571428571%', 'Dataset 4': '42.76785714285714%'}
# --------------------------------------------------------------------------------
# Batch 36
# {12: 'Dataset 2', 4: 'Dataset 2', 3: 'Dataset 2', 23: 'Dataset 2', 11: 'Dataset 2', 412: 'Dataset 4', 435: 'Dataset 4', 91: 'Dataset 3', 35: 'Dataset 2', 24: 'Dataset 3', 141: 'Dataset 4'}
# Running counter: {'Dataset 1': 34, 'Dataset 2': 194, 'Dataset 3': 434, 'Dataset 4': 490}
# Running percentages: {'Dataset 1': '2.951388888888889%', 'Dataset 2': '16.84027777777778%', 'Dataset 3': '37.67361111111111%', 'Dataset 4': '42.53472222222222%'}
# --------------------------------------------------------------------------------
# Batch 37
# {141: 'Dataset 4', 42: 'Dataset 2', 8: 'Dataset 2', 49: 'Dataset 4', 97: 'Dataset 3', 56: 'Dataset 4', 269: 'Dataset 4', 93: 'Dataset 3', 77: 'Dataset 3', 0: 'Dataset 1', 21: 'Dataset 2', 22: 'Dataset 3', 187: 'Dataset 4', 40: 'Dataset 2', 78: 'Dataset 3', 14: 'Dataset 3'}
# Running counter: {'Dataset 1': 35, 'Dataset 2': 200, 'Dataset 3': 448, 'Dataset 4': 501}
# Running percentages: {'Dataset 1': '2.956081081081081%', 'Dataset 2': '16.89189189189189%', 'Dataset 3': '37.83783783783784%', 'Dataset 4': '42.314189189189186%'}
# --------------------------------------------------------------------------------
# Batch 38
# {14: 'Dataset 3', 420: 'Dataset 4', 54: 'Dataset 3', 7: 'Dataset 1', 411: 'Dataset 4', 87: 'Dataset 4', 22: 'Dataset 2', 63: 'Dataset 4', 65: 'Dataset 3', 32: 'Dataset 3'}
# Running counter: {'Dataset 1': 36, 'Dataset 2': 204, 'Dataset 3': 459, 'Dataset 4': 517}
# Running percentages: {'Dataset 1': '2.9605263157894735%', 'Dataset 2': '16.776315789473685%', 'Dataset 3': '37.74671052631579%', 'Dataset 4': '42.51644736842105%'}
# --------------------------------------------------------------------------------
# Batch 39
# {32: 'Dataset 3', 94: 'Dataset 4', 29: 'Dataset 2', 389: 'Dataset 4', 96: 'Dataset 3', 154: 'Dataset 4', 1: 'Dataset 2', 24: 'Dataset 4', 95: 'Dataset 3', 66: 'Dataset 3'}
# Running counter: {'Dataset 1': 36, 'Dataset 2': 207, 'Dataset 3': 476, 'Dataset 4': 529}
# Running percentages: {'Dataset 1': '2.8846153846153846%', 'Dataset 2': '16.58653846153846%', 'Dataset 3': '38.141025641025635%', 'Dataset 4': '42.38782051282051%'}
# --------------------------------------------------------------------------------
# Batch 40
# {66: 'Dataset 3', 16: 'Dataset 2', 413: 'Dataset 4', 1: 'Dataset 2', 399: 'Dataset 4', 0: 'Dataset 2', 428: 'Dataset 4', 68: 'Dataset 3', 30: 'Dataset 2', 20: 'Dataset 2', 29: 'Dataset 3', 24: 'Dataset 2', 233: 'Dataset 4', 101: 'Dataset 4'}
# Running counter: {'Dataset 1': 36, 'Dataset 2': 216, 'Dataset 3': 485, 'Dataset 4': 543}
# Running percentages: {'Dataset 1': '2.8125%', 'Dataset 2': '16.875%', 'Dataset 3': '37.890625%', 'Dataset 4': '42.421875%'}
# --------------------------------------------------------------------------------
# Batch 41
# {101: 'Dataset 4', 40: 'Dataset 3', 326: 'Dataset 4', 177: 'Dataset 4', 442: 'Dataset 4', 418: 'Dataset 4', 405: 'Dataset 4', 75: 'Dataset 3', 93: 'Dataset 3', 65: 'Dataset 4', 8: 'Dataset 1', 32: 'Dataset 2'}
# Running counter: {'Dataset 1': 37, 'Dataset 2': 218, 'Dataset 3': 498, 'Dataset 4': 559}
# Running percentages: {'Dataset 1': '2.8201219512195124%', 'Dataset 2': '16.615853658536587%', 'Dataset 3': '37.957317073170735%', 'Dataset 4': '42.60670731707317%'}
# --------------------------------------------------------------------------------
# Batch 42
# {65: 'Dataset 4', 452: 'Dataset 4', 47: 'Dataset 3', 17: 'Dataset 3', 97: 'Dataset 3', 100: 'Dataset 4', 38: 'Dataset 3', 4: 'Dataset 3', 417: 'Dataset 4', 2: 'Dataset 3', 41: 'Dataset 3', 26: 'Dataset 2', 16: 'Dataset 2', 71: 'Dataset 3', 55: 'Dataset 3'}
# Running counter: {'Dataset 1': 37, 'Dataset 2': 220, 'Dataset 3': 518, 'Dataset 4': 569}
# Running percentages: {'Dataset 1': '2.7529761904761902%', 'Dataset 2': '16.36904761904762%', 'Dataset 3': '38.54166666666667%', 'Dataset 4': '42.336309523809526%'}
# --------------------------------------------------------------------------------
# Batch 43
# {97: 'Dataset 3', 85: 'Dataset 3', 44: 'Dataset 3', 25: 'Dataset 2', 21: 'Dataset 3', 37: 'Dataset 2', 58: 'Dataset 3', 89: 'Dataset 3', 79: 'Dataset 3', 340: 'Dataset 4', 15: 'Dataset 3', 400: 'Dataset 4'}
# Running counter: {'Dataset 1': 37, 'Dataset 2': 223, 'Dataset 3': 540, 'Dataset 4': 576}
# Running percentages: {'Dataset 1': '2.688953488372093%', 'Dataset 2': '16.206395348837212%', 'Dataset 3': '39.24418604651162%', 'Dataset 4': '41.86046511627907%'}
# --------------------------------------------------------------------------------
# Batch 44
# {400: 'Dataset 4', 29: 'Dataset 3', 38: 'Dataset 3', 33: 'Dataset 2', 23: 'Dataset 4', 90: 'Dataset 3', 110: 'Dataset 4', 49: 'Dataset 2', 41: 'Dataset 2', 65: 'Dataset 3', 437: 'Dataset 4', 42: 'Dataset 2', 157: 'Dataset 4', 4: 'Dataset 1'}
# Running counter: {'Dataset 1': 38, 'Dataset 2': 231, 'Dataset 3': 552, 'Dataset 4': 587}
# Running percentages: {'Dataset 1': '2.6988636363636362%', 'Dataset 2': '16.40625%', 'Dataset 3': '39.20454545454545%', 'Dataset 4': '41.690340909090914%'}
# --------------------------------------------------------------------------------
# Batch 45
# {140: 'Dataset 4', 2: 'Dataset 1', 73: 'Dataset 3', 42: 'Dataset 2', 44: 'Dataset 2', 1: 'Dataset 1', 8: 'Dataset 2', 25: 'Dataset 3', 124: 'Dataset 4', 45: 'Dataset 2', 448: 'Dataset 4', 88: 'Dataset 3', 13: 'Dataset 4', 76: 'Dataset 3', 72: 'Dataset 3', 19: 'Dataset 2', 367: 'Dataset 4'}
# Running counter: {'Dataset 1': 40, 'Dataset 2': 240, 'Dataset 3': 562, 'Dataset 4': 598}
# Running percentages: {'Dataset 1': '2.7777777777777777%', 'Dataset 2': '16.666666666666664%', 'Dataset 3': '39.02777777777778%', 'Dataset 4': '41.52777777777778%'}
# --------------------------------------------------------------------------------
# Batch 46
# {367: 'Dataset 4', 8: 'Dataset 1', 359: 'Dataset 4', 10: 'Dataset 3', 16: 'Dataset 3', 2: 'Dataset 1', 468: 'Dataset 4', 79: 'Dataset 3', 6: 'Dataset 2', 21: 'Dataset 3', 5: 'Dataset 1', 40: 'Dataset 2', 53: 'Dataset 3', 78: 'Dataset 3', 479: 'Dataset 4'}
# Running counter: {'Dataset 1': 43, 'Dataset 2': 244, 'Dataset 3': 577, 'Dataset 4': 608}
# Running percentages: {'Dataset 1': '2.921195652173913%', 'Dataset 2': '16.57608695652174%', 'Dataset 3': '39.19836956521739%', 'Dataset 4': '41.30434782608695%'}
# --------------------------------------------------------------------------------
# Batch 47
# {139: 'Dataset 4', 16: 'Dataset 3', 49: 'Dataset 3', 3: 'Dataset 3', 370: 'Dataset 4', 66: 'Dataset 3', 2: 'Dataset 2', 88: 'Dataset 3', 85: 'Dataset 3', 50: 'Dataset 3', 472: 'Dataset 4'}
# Running counter: {'Dataset 1': 43, 'Dataset 2': 245, 'Dataset 3': 599, 'Dataset 4': 617}
# Running percentages: {'Dataset 1': '2.859042553191489%', 'Dataset 2': '16.289893617021274%', 'Dataset 3': '39.827127659574465%', 'Dataset 4': '41.023936170212764%'}
# --------------------------------------------------------------------------------
# Batch 48
# {16: 'Dataset 3', 30: 'Dataset 3', 488: 'Dataset 4', 320: 'Dataset 4', 6: 'Dataset 3', 8: 'Dataset 1', 70: 'Dataset 3', 325: 'Dataset 4', 175: 'Dataset 4', 131: 'Dataset 4', 92: 'Dataset 3'}
# Running counter: {'Dataset 1': 44, 'Dataset 2': 246, 'Dataset 3': 612, 'Dataset 4': 634}
# Running percentages: {'Dataset 1': '2.864583333333333%', 'Dataset 2': '16.015625%', 'Dataset 3': '39.84375%', 'Dataset 4': '41.27604166666667%'}
# --------------------------------------------------------------------------------
# Batch 49
# {256: 'Dataset 4', 40: 'Dataset 2', 78: 'Dataset 3', 28: 'Dataset 2', 459: 'Dataset 4', 0: 'Dataset 1', 5: 'Dataset 1', 108: 'Dataset 4', 53: 'Dataset 3', 266: 'Dataset 4', 461: 'Dataset 4', 407: 'Dataset 4'}
# Running counter: {'Dataset 1': 47, 'Dataset 2': 250, 'Dataset 3': 620, 'Dataset 4': 651}
# Running percentages: {'Dataset 1': '2.9974489795918364%', 'Dataset 2': '15.943877551020408%', 'Dataset 3': '39.54081632653062%', 'Dataset 4': '41.517857142857146%'}
# --------------------------------------------------------------------------------
# Batch 50
# {407: 'Dataset 4', 305: 'Dataset 4', 25: 'Dataset 2', 81: 'Dataset 3', 292: 'Dataset 4', 12: 'Dataset 4', 66: 'Dataset 4', 36: 'Dataset 3', 44: 'Dataset 3', 10: 'Dataset 3', 491: 'Dataset 4', 451: 'Dataset 4', 19: 'Dataset 2'}
# Running counter: {'Dataset 1': 47, 'Dataset 2': 252, 'Dataset 3': 632, 'Dataset 4': 669}
# Running percentages: {'Dataset 1': '2.9375%', 'Dataset 2': '15.75%', 'Dataset 3': '39.5%', 'Dataset 4': '41.8125%'}
# --------------------------------------------------------------------------------
# Batch 51
# {36: 'Dataset 3', 31: 'Dataset 3', 35: 'Dataset 3', 26: 'Dataset 2', 9: 'Dataset 2', 99: 'Dataset 4', 23: 'Dataset 2', 30: 'Dataset 3', 360: 'Dataset 4', 15: 'Dataset 3', 92: 'Dataset 3', 166: 'Dataset 4', 0: 'Dataset 3'}
# Running counter: {'Dataset 1': 47, 'Dataset 2': 256, 'Dataset 3': 654, 'Dataset 4': 675}
# Running percentages: {'Dataset 1': '2.8799019607843137%', 'Dataset 2': '15.686274509803921%', 'Dataset 3': '40.07352941176471%', 'Dataset 4': '41.36029411764706%'}
# --------------------------------------------------------------------------------
# Batch 52
# {24: 'Dataset 2', 28: 'Dataset 3', 81: 'Dataset 3', 111: 'Dataset 4', 495: 'Dataset 4', 52: 'Dataset 3', 42: 'Dataset 3', 4: 'Dataset 2', 463: 'Dataset 4', 387: 'Dataset 4', 50: 'Dataset 3', 48: 'Dataset 2', 0: 'Dataset 1'}
# Running counter: {'Dataset 1': 48, 'Dataset 2': 263, 'Dataset 3': 665, 'Dataset 4': 688}
# Running percentages: {'Dataset 1': '2.8846153846153846%', 'Dataset 2': '15.805288461538462%', 'Dataset 3': '39.96394230769231%', 'Dataset 4': '41.34615384615385%'}
# --------------------------------------------------------------------------------
# Batch 53
# {48: 'Dataset 2', 43: 'Dataset 2', 9: 'Dataset 1', 82: 'Dataset 3', 298: 'Dataset 4', 392: 'Dataset 4', 94: 'Dataset 3', 484: 'Dataset 4', 3: 'Dataset 3', 70: 'Dataset 3', 23: 'Dataset 3', 439: 'Dataset 4'}
# Running counter: {'Dataset 1': 49, 'Dataset 2': 268, 'Dataset 3': 679, 'Dataset 4': 700}
# Running percentages: {'Dataset 1': '2.8891509433962264%', 'Dataset 2': '15.80188679245283%', 'Dataset 3': '40.035377358490564%', 'Dataset 4': '41.27358490566038%'}
# --------------------------------------------------------------------------------
# Batch 54
# {27: 'Dataset 2', 90: 'Dataset 3', 0: 'Dataset 1', 32: 'Dataset 2', 218: 'Dataset 4', 4: 'Dataset 1', 2: 'Dataset 3', 348: 'Dataset 4', 35: 'Dataset 2', 66: 'Dataset 3', 1: 'Dataset 1', 323: 'Dataset 4', 121: 'Dataset 4'}
# Running counter: {'Dataset 1': 52, 'Dataset 2': 276, 'Dataset 3': 689, 'Dataset 4': 711}
# Running percentages: {'Dataset 1': '3.009259259259259%', 'Dataset 2': '15.972222222222221%', 'Dataset 3': '39.87268518518518%', 'Dataset 4': '41.14583333333333%'}
# --------------------------------------------------------------------------------
# Batch 55
# {121: 'Dataset 4', 7: 'Dataset 1', 9: 'Dataset 1', 19: 'Dataset 3', 99: 'Dataset 3', 43: 'Dataset 2', 68: 'Dataset 3', 447: 'Dataset 4', 249: 'Dataset 4', 465: 'Dataset 4', 430: 'Dataset 4', 3: 'Dataset 2', 23: 'Dataset 2'}
# Running counter: {'Dataset 1': 54, 'Dataset 2': 284, 'Dataset 3': 702, 'Dataset 4': 720}
# Running percentages: {'Dataset 1': '3.0681818181818183%', 'Dataset 2': '16.136363636363637%', 'Dataset 3': '39.88636363636363%', 'Dataset 4': '40.909090909090914%'}
# --------------------------------------------------------------------------------
# Batch 56
# {23: 'Dataset 2', 2: 'Dataset 3', 28: 'Dataset 3', 318: 'Dataset 4', 1: 'Dataset 3', 94: 'Dataset 3', 126: 'Dataset 4', 34: 'Dataset 4', 61: 'Dataset 3', 13: 'Dataset 2', 212: 'Dataset 4', 47: 'Dataset 3', 79: 'Dataset 4', 6: 'Dataset 3', 347: 'Dataset 4', 42: 'Dataset 2', 76: 'Dataset 3'}
# Running counter: {'Dataset 1': 54, 'Dataset 2': 288, 'Dataset 3': 719, 'Dataset 4': 731}
# Running percentages: {'Dataset 1': '3.013392857142857%', 'Dataset 2': '16.071428571428573%', 'Dataset 3': '40.122767857142854%', 'Dataset 4': '40.792410714285715%'}
# --------------------------------------------------------------------------------
# Batch 57
# {76: 'Dataset 3', 47: 'Dataset 2', 98: 'Dataset 3', 18: 'Dataset 2', 82: 'Dataset 4', 0: 'Dataset 1', 46: 'Dataset 2', 2: 'Dataset 1', 263: 'Dataset 4', 63: 'Dataset 3', 204: 'Dataset 4', 36: 'Dataset 2', 119: 'Dataset 4', 43: 'Dataset 3', 35: 'Dataset 2', 525: 'Dataset 4', 397: 'Dataset 4', 49: 'Dataset 3'}
# Running counter: {'Dataset 1': 56, 'Dataset 2': 294, 'Dataset 3': 729, 'Dataset 4': 745}
# Running percentages: {'Dataset 1': '3.070175438596491%', 'Dataset 2': '16.11842105263158%', 'Dataset 3': '39.96710526315789%', 'Dataset 4': '40.844298245614034%'}
# --------------------------------------------------------------------------------
# Batch 58
# {49: 'Dataset 3', 471: 'Dataset 4', 14: 'Dataset 2', 39: 'Dataset 2', 68: 'Dataset 3', 44: 'Dataset 2', 221: 'Dataset 4', 206: 'Dataset 4', 34: 'Dataset 3', 199: 'Dataset 4', 93: 'Dataset 3', 43: 'Dataset 3', 467: 'Dataset 4'}
# Running counter: {'Dataset 1': 56, 'Dataset 2': 300, 'Dataset 3': 741, 'Dataset 4': 759}
# Running percentages: {'Dataset 1': '3.0172413793103448%', 'Dataset 2': '16.163793103448278%', 'Dataset 3': '39.924568965517246%', 'Dataset 4': '40.894396551724135%'}
# --------------------------------------------------------------------------------
# Batch 59
# {467: 'Dataset 4', 398: 'Dataset 4', 344: 'Dataset 4', 5: 'Dataset 1', 1: 'Dataset 1', 6: 'Dataset 3', 17: 'Dataset 2', 54: 'Dataset 3', 375: 'Dataset 4', 27: 'Dataset 3', 9: 'Dataset 2', 14: 'Dataset 3', 85: 'Dataset 3', 275: 'Dataset 4'}
# Running counter: {'Dataset 1': 58, 'Dataset 2': 302, 'Dataset 3': 755, 'Dataset 4': 773}
# Running percentages: {'Dataset 1': '3.0720338983050848%', 'Dataset 2': '15.995762711864407%', 'Dataset 3': '39.98940677966102%', 'Dataset 4': '40.94279661016949%'}
# --------------------------------------------------------------------------------
# Batch 60
# {40: 'Dataset 3', 89: 'Dataset 3', 1: 'Dataset 1', 10: 'Dataset 2', 23: 'Dataset 2', 17: 'Dataset 3', 67: 'Dataset 3', 53: 'Dataset 3', 31: 'Dataset 3', 52: 'Dataset 3', 28: 'Dataset 3', 95: 'Dataset 3', 30: 'Dataset 3', 365: 'Dataset 4', 48: 'Dataset 2'}
# Running counter: {'Dataset 1': 59, 'Dataset 2': 306, 'Dataset 3': 778, 'Dataset 4': 777}
# Running percentages: {'Dataset 1': '3.0729166666666665%', 'Dataset 2': '15.937499999999998%', 'Dataset 3': '40.520833333333336%', 'Dataset 4': '40.46875%'}
# --------------------------------------------------------------------------------
# Batch 61
# {15: 'Dataset 3', 46: 'Dataset 3', 487: 'Dataset 4', 11: 'Dataset 3', 31: 'Dataset 2', 63: 'Dataset 3', 533: 'Dataset 4', 37: 'Dataset 3', 70: 'Dataset 4', 303: 'Dataset 4'}
# Running counter: {'Dataset 1': 59, 'Dataset 2': 309, 'Dataset 3': 797, 'Dataset 4': 787}
# Running percentages: {'Dataset 1': '3.0225409836065573%', 'Dataset 2': '15.829918032786885%', 'Dataset 3': '40.829918032786885%', 'Dataset 4': '40.31762295081967%'}
# --------------------------------------------------------------------------------
# Batch 62
# {303: 'Dataset 4', 50: 'Dataset 3', 36: 'Dataset 3', 96: 'Dataset 3', 7: 'Dataset 2', 406: 'Dataset 4', 534: 'Dataset 4', 556: 'Dataset 4', 91: 'Dataset 4', 371: 'Dataset 4', 500: 'Dataset 4'}
# Running counter: {'Dataset 1': 59, 'Dataset 2': 310, 'Dataset 3': 806, 'Dataset 4': 809}
# Running percentages: {'Dataset 1': '2.9737903225806455%', 'Dataset 2': '15.625%', 'Dataset 3': '40.625%', 'Dataset 4': '40.77620967741936%'}
# --------------------------------------------------------------------------------
# Batch 63
# {500: 'Dataset 4', 24: 'Dataset 2', 227: 'Dataset 4', 80: 'Dataset 3', 9: 'Dataset 2', 19: 'Dataset 3', 0: 'Dataset 2', 21: 'Dataset 3', 53: 'Dataset 3', 30: 'Dataset 2', 39: 'Dataset 2', 512: 'Dataset 4', 27: 'Dataset 2', 374: 'Dataset 4'}
# Running counter: {'Dataset 1': 59, 'Dataset 2': 319, 'Dataset 3': 819, 'Dataset 4': 819}
# Running percentages: {'Dataset 1': '2.9265873015873014%', 'Dataset 2': '15.823412698412698%', 'Dataset 3': '40.625%', 'Dataset 4': '40.625%'}
# --------------------------------------------------------------------------------
# Batch 64
# {245: 'Dataset 4', 59: 'Dataset 3', 45: 'Dataset 2', 21: 'Dataset 2', 54: 'Dataset 3', 0: 'Dataset 2', 37: 'Dataset 2', 48: 'Dataset 4', 38: 'Dataset 3', 477: 'Dataset 4', 50: 'Dataset 4', 453: 'Dataset 4', 436: 'Dataset 4', 82: 'Dataset 3'}
# Running counter: {'Dataset 1': 59, 'Dataset 2': 326, 'Dataset 3': 829, 'Dataset 4': 834}
# Running percentages: {'Dataset 1': '2.880859375%', 'Dataset 2': '15.91796875%', 'Dataset 3': '40.478515625%', 'Dataset 4': '40.72265625%'}
# --------------------------------------------------------------------------------
# Batch 65
# {82: 'Dataset 3', 112: 'Dataset 4', 489: 'Dataset 4', 38: 'Dataset 3', 1: 'Dataset 1', 71: 'Dataset 3', 79: 'Dataset 3', 88: 'Dataset 3', 12: 'Dataset 3', 514: 'Dataset 4'}
# Running counter: {'Dataset 1': 60, 'Dataset 2': 326, 'Dataset 3': 849, 'Dataset 4': 845}
# Running percentages: {'Dataset 1': '2.8846153846153846%', 'Dataset 2': '15.673076923076923%', 'Dataset 3': '40.81730769230769%', 'Dataset 4': '40.625%'}
# --------------------------------------------------------------------------------
# Batch 66
# {514: 'Dataset 4', 17: 'Dataset 3', 5: 'Dataset 1', 29: 'Dataset 2', 1: 'Dataset 2', 456: 'Dataset 4', 33: 'Dataset 2', 163: 'Dataset 4', 445: 'Dataset 4', 300: 'Dataset 4', 81: 'Dataset 3', 58: 'Dataset 3', 25: 'Dataset 2'}
# Running counter: {'Dataset 1': 61, 'Dataset 2': 336, 'Dataset 3': 857, 'Dataset 4': 858}
# Running percentages: {'Dataset 1': '2.8882575757575757%', 'Dataset 2': '15.909090909090908%', 'Dataset 3': '40.577651515151516%', 'Dataset 4': '40.625%'}
# --------------------------------------------------------------------------------
# Batch 67
# {25: 'Dataset 3', 3: 'Dataset 2', 6: 'Dataset 2', 30: 'Dataset 3', 27: 'Dataset 4', 13: 'Dataset 3', 458: 'Dataset 4', 72: 'Dataset 3', 44: 'Dataset 2', 68: 'Dataset 3', 15: 'Dataset 3'}
# Running counter: {'Dataset 1': 61, 'Dataset 2': 346, 'Dataset 3': 875, 'Dataset 4': 862}
# Running percentages: {'Dataset 1': '2.845149253731343%', 'Dataset 2': '16.138059701492537%', 'Dataset 3': '40.8115671641791%', 'Dataset 4': '40.20522388059701%'}
# --------------------------------------------------------------------------------
# Batch 68
# {15: 'Dataset 3', 4: 'Dataset 1', 504: 'Dataset 4', 376: 'Dataset 4', 1: 'Dataset 2', 74: 'Dataset 3', 68: 'Dataset 3', 2: 'Dataset 1', 554: 'Dataset 4', 17: 'Dataset 2', 210: 'Dataset 4', 16: 'Dataset 3', 3: 'Dataset 1', 93: 'Dataset 3', 474: 'Dataset 4'}
# Running counter: {'Dataset 1': 64, 'Dataset 2': 348, 'Dataset 3': 889, 'Dataset 4': 875}
# Running percentages: {'Dataset 1': '2.941176470588235%', 'Dataset 2': '15.992647058823529%', 'Dataset 3': '40.85477941176471%', 'Dataset 4': '40.21139705882353%'}
# --------------------------------------------------------------------------------
# Batch 69
# {80: 'Dataset 4', 15: 'Dataset 2', 1: 'Dataset 2', 47: 'Dataset 2', 17: 'Dataset 2', 66: 'Dataset 3', 5: 'Dataset 3', 8: 'Dataset 2', 32: 'Dataset 3', 404: 'Dataset 4', 106: 'Dataset 4', 414: 'Dataset 4'}
# Running counter: {'Dataset 1': 64, 'Dataset 2': 356, 'Dataset 3': 897, 'Dataset 4': 891}
# Running percentages: {'Dataset 1': '2.898550724637681%', 'Dataset 2': '16.1231884057971%', 'Dataset 3': '40.625%', 'Dataset 4': '40.35326086956522%'}
# --------------------------------------------------------------------------------
# Batch 70
# {478: 'Dataset 4', 329: 'Dataset 4', 86: 'Dataset 3', 48: 'Dataset 3', 36: 'Dataset 2', 38: 'Dataset 4', 4: 'Dataset 2', 283: 'Dataset 4', 5: 'Dataset 2', 507: 'Dataset 4', 87: 'Dataset 3', 550: 'Dataset 4', 79: 'Dataset 3', 46: 'Dataset 3', 509: 'Dataset 4', 47: 'Dataset 2'}
# Running counter: {'Dataset 1': 64, 'Dataset 2': 363, 'Dataset 3': 910, 'Dataset 4': 903}
# Running percentages: {'Dataset 1': '2.857142857142857%', 'Dataset 2': '16.205357142857142%', 'Dataset 3': '40.625%', 'Dataset 4': '40.3125%'}
# --------------------------------------------------------------------------------
# Batch 71
# {23: 'Dataset 3', 476: 'Dataset 4', 138: 'Dataset 4', 1: 'Dataset 2', 183: 'Dataset 4', 41: 'Dataset 3', 44: 'Dataset 3', 526: 'Dataset 4', 19: 'Dataset 3', 45: 'Dataset 3', 8: 'Dataset 3', 25: 'Dataset 2', 4: 'Dataset 3', 37: 'Dataset 2'}
# Running counter: {'Dataset 1': 65, 'Dataset 2': 368, 'Dataset 3': 928, 'Dataset 4': 911}
# Running percentages: {'Dataset 1': '2.8609154929577465%', 'Dataset 2': '16.19718309859155%', 'Dataset 3': '40.845070422535215%', 'Dataset 4': '40.096830985915496%'}
# --------------------------------------------------------------------------------
# Batch 72
# {95: 'Dataset 3', 12: 'Dataset 2', 47: 'Dataset 2', 598: 'Dataset 4', 4: 'Dataset 1', 602: 'Dataset 4', 335: 'Dataset 4', 10: 'Dataset 2', 593: 'Dataset 4', 3: 'Dataset 2', 21: 'Dataset 2', 65: 'Dataset 3', 2: 'Dataset 1', 0: 'Dataset 1', 6: 'Dataset 3', 60: 'Dataset 3'}
# Running counter: {'Dataset 1': 69, 'Dataset 2': 377, 'Dataset 3': 936, 'Dataset 4': 922}
# Running percentages: {'Dataset 1': '2.994791666666667%', 'Dataset 2': '16.36284722222222%', 'Dataset 3': '40.625%', 'Dataset 4': '40.01736111111111%'}
# --------------------------------------------------------------------------------
# Batch 73
# {60: 'Dataset 3', 520: 'Dataset 4', 105: 'Dataset 4', 589: 'Dataset 4', 66: 'Dataset 3', 39: 'Dataset 3', 6: 'Dataset 2', 114: 'Dataset 4', 230: 'Dataset 4', 169: 'Dataset 4', 423: 'Dataset 4'}
# Running counter: {'Dataset 1': 69, 'Dataset 2': 378, 'Dataset 3': 939, 'Dataset 4': 950}
# Running percentages: {'Dataset 1': '2.953767123287671%', 'Dataset 2': '16.18150684931507%', 'Dataset 3': '40.196917808219176%', 'Dataset 4': '40.667808219178085%'}
# --------------------------------------------------------------------------------
# Batch 74
# {568: 'Dataset 4', 35: 'Dataset 2', 426: 'Dataset 4', 88: 'Dataset 4', 26: 'Dataset 3', 62: 'Dataset 3', 25: 'Dataset 4', 16: 'Dataset 3', 56: 'Dataset 3', 39: 'Dataset 4', 14: 'Dataset 2', 84: 'Dataset 3'}
# Running counter: {'Dataset 1': 69, 'Dataset 2': 383, 'Dataset 3': 956, 'Dataset 4': 960}
# Running percentages: {'Dataset 1': '2.9138513513513513%', 'Dataset 2': '16.173986486486484%', 'Dataset 3': '40.37162162162162%', 'Dataset 4': '40.54054054054054%'}
# --------------------------------------------------------------------------------
# Batch 75
# {5: 'Dataset 3', 19: 'Dataset 2', 42: 'Dataset 3', 517: 'Dataset 4', 31: 'Dataset 2', 485: 'Dataset 4', 96: 'Dataset 3', 9: 'Dataset 1', 73: 'Dataset 3', 14: 'Dataset 4', 27: 'Dataset 3', 524: 'Dataset 4', 299: 'Dataset 4', 308: 'Dataset 4', 41: 'Dataset 2', 553: 'Dataset 4'}
# Running counter: {'Dataset 1': 70, 'Dataset 2': 389, 'Dataset 3': 965, 'Dataset 4': 976}
# Running percentages: {'Dataset 1': '2.9166666666666665%', 'Dataset 2': '16.208333333333332%', 'Dataset 3': '40.208333333333336%', 'Dataset 4': '40.666666666666664%'}
# --------------------------------------------------------------------------------
# Batch 76
# {553: 'Dataset 4', 35: 'Dataset 3', 144: 'Dataset 4', 545: 'Dataset 4', 6: 'Dataset 1', 3: 'Dataset 4', 83: 'Dataset 3', 15: 'Dataset 2', 0: 'Dataset 1', 239: 'Dataset 4', 24: 'Dataset 2', 172: 'Dataset 4', 9: 'Dataset 1'}
# Running counter: {'Dataset 1': 73, 'Dataset 2': 393, 'Dataset 3': 974, 'Dataset 4': 992}
# Running percentages: {'Dataset 1': '3.0016447368421053%', 'Dataset 2': '16.159539473684212%', 'Dataset 3': '40.04934210526316%', 'Dataset 4': '40.78947368421053%'}
# --------------------------------------------------------------------------------
# Batch 77
# {78: 'Dataset 3', 48: 'Dataset 2', 75: 'Dataset 3', 460: 'Dataset 4', 9: 'Dataset 3', 21: 'Dataset 2', 20: 'Dataset 3', 573: 'Dataset 4', 32: 'Dataset 2', 6: 'Dataset 1', 10: 'Dataset 2', 597: 'Dataset 4', 69: 'Dataset 3'}
# Running counter: {'Dataset 1': 74, 'Dataset 2': 399, 'Dataset 3': 990, 'Dataset 4': 1001}
# Running percentages: {'Dataset 1': '3.0032467532467533%', 'Dataset 2': '16.193181818181817%', 'Dataset 3': '40.17857142857143%', 'Dataset 4': '40.625%'}
# --------------------------------------------------------------------------------
# Batch 78
# {56: 'Dataset 3', 612: 'Dataset 4', 2: 'Dataset 1', 12: 'Dataset 2', 446: 'Dataset 4', 0: 'Dataset 2', 45: 'Dataset 3', 10: 'Dataset 2', 60: 'Dataset 4', 72: 'Dataset 3', 77: 'Dataset 3', 513: 'Dataset 4', 572: 'Dataset 4'}
# Running counter: {'Dataset 1': 75, 'Dataset 2': 403, 'Dataset 3': 996, 'Dataset 4': 1022}
# Running percentages: {'Dataset 1': '3.0048076923076925%', 'Dataset 2': '16.145833333333336%', 'Dataset 3': '39.90384615384615%', 'Dataset 4': '40.94551282051282%'}
# --------------------------------------------------------------------------------
# Batch 79
# {572: 'Dataset 4', 35: 'Dataset 4', 5: 'Dataset 1', 2: 'Dataset 3', 628: 'Dataset 4', 45: 'Dataset 2', 1: 'Dataset 1', 508: 'Dataset 4', 68: 'Dataset 3', 37: 'Dataset 3', 61: 'Dataset 3'}
# Running counter: {'Dataset 1': 77, 'Dataset 2': 405, 'Dataset 3': 1014, 'Dataset 4': 1032}
# Running percentages: {'Dataset 1': '3.045886075949367%', 'Dataset 2': '16.020569620253163%', 'Dataset 3': '40.110759493670884%', 'Dataset 4': '40.822784810126585%'}
# --------------------------------------------------------------------------------
# Batch 80
# {12: 'Dataset 3', 431: 'Dataset 4', 4: 'Dataset 1', 28: 'Dataset 2', 636: 'Dataset 4', 313: 'Dataset 4', 422: 'Dataset 4', 48: 'Dataset 2', 0: 'Dataset 3', 57: 'Dataset 3', 291: 'Dataset 4', 51: 'Dataset 3', 61: 'Dataset 3'}
# Running counter: {'Dataset 1': 78, 'Dataset 2': 409, 'Dataset 3': 1026, 'Dataset 4': 1047}
# Running percentages: {'Dataset 1': '3.046875%', 'Dataset 2': '15.9765625%', 'Dataset 3': '40.078125%', 'Dataset 4': '40.8984375%'}
# --------------------------------------------------------------------------------
# Batch 81
# {268: 'Dataset 4', 59: 'Dataset 3', 385: 'Dataset 4', 569: 'Dataset 4', 610: 'Dataset 4', 64: 'Dataset 4', 560: 'Dataset 4', 552: 'Dataset 4', 84: 'Dataset 3', 339: 'Dataset 4', 92: 'Dataset 3', 584: 'Dataset 4', 74: 'Dataset 3', 409: 'Dataset 4'}
# Running counter: {'Dataset 1': 78, 'Dataset 2': 409, 'Dataset 3': 1034, 'Dataset 4': 1071}
# Running percentages: {'Dataset 1': '3.009259259259259%', 'Dataset 2': '15.779320987654321%', 'Dataset 3': '39.891975308641975%', 'Dataset 4': '41.31944444444444%'}
# --------------------------------------------------------------------------------
# Batch 82
# {409: 'Dataset 4', 48: 'Dataset 3', 71: 'Dataset 3', 408: 'Dataset 4', 521: 'Dataset 4', 630: 'Dataset 4', 543: 'Dataset 4', 56: 'Dataset 3', 563: 'Dataset 4', 555: 'Dataset 4', 45: 'Dataset 2', 7: 'Dataset 2', 161: 'Dataset 4', 466: 'Dataset 4'}
# Running counter: {'Dataset 1': 78, 'Dataset 2': 412, 'Dataset 3': 1040, 'Dataset 4': 1094}
# Running percentages: {'Dataset 1': '2.972560975609756%', 'Dataset 2': '15.701219512195122%', 'Dataset 3': '39.63414634146341%', 'Dataset 4': '41.69207317073171%'}
# --------------------------------------------------------------------------------
# Batch 83
# {466: 'Dataset 4', 24: 'Dataset 3', 0: 'Dataset 1', 547: 'Dataset 4', 546: 'Dataset 4', 9: 'Dataset 3', 98: 'Dataset 3', 39: 'Dataset 3', 36: 'Dataset 2', 217: 'Dataset 4', 16: 'Dataset 2'}
# Running counter: {'Dataset 1': 79, 'Dataset 2': 416, 'Dataset 3': 1057, 'Dataset 4': 1104}
# Running percentages: {'Dataset 1': '2.9743975903614457%', 'Dataset 2': '15.66265060240964%', 'Dataset 3': '39.79668674698795%', 'Dataset 4': '41.566265060240966%'}
# --------------------------------------------------------------------------------
# Batch 84
# {425: 'Dataset 4', 40: 'Dataset 2', 18: 'Dataset 2', 201: 'Dataset 4', 45: 'Dataset 3', 91: 'Dataset 3', 2: 'Dataset 2', 30: 'Dataset 3', 16: 'Dataset 3', 421: 'Dataset 4', 647: 'Dataset 4'}
# Running counter: {'Dataset 1': 79, 'Dataset 2': 423, 'Dataset 3': 1070, 'Dataset 4': 1116}
# Running percentages: {'Dataset 1': '2.9389880952380953%', 'Dataset 2': '15.736607142857142%', 'Dataset 3': '39.80654761904761%', 'Dataset 4': '41.517857142857146%'}
# --------------------------------------------------------------------------------
# Batch 85
# {647: 'Dataset 4', 8: 'Dataset 1', 55: 'Dataset 3', 9: 'Dataset 1', 3: 'Dataset 1', 43: 'Dataset 2', 53: 'Dataset 3', 5: 'Dataset 2', 13: 'Dataset 2', 25: 'Dataset 3', 44: 'Dataset 3', 20: 'Dataset 2', 540: 'Dataset 4', 1: 'Dataset 3'}
# Running counter: {'Dataset 1': 83, 'Dataset 2': 432, 'Dataset 3': 1087, 'Dataset 4': 1118}
# Running percentages: {'Dataset 1': '3.051470588235294%', 'Dataset 2': '15.88235294117647%', 'Dataset 3': '39.96323529411765%', 'Dataset 4': '41.10294117647059%'}
# --------------------------------------------------------------------------------
# Batch 86
# {1: 'Dataset 3', 47: 'Dataset 3', 280: 'Dataset 4', 27: 'Dataset 2', 11: 'Dataset 2', 23: 'Dataset 3', 579: 'Dataset 4', 30: 'Dataset 2', 496: 'Dataset 4', 20: 'Dataset 2', 21: 'Dataset 3', 55: 'Dataset 3'}
# Running counter: {'Dataset 1': 83, 'Dataset 2': 438, 'Dataset 3': 1104, 'Dataset 4': 1127}
# Running percentages: {'Dataset 1': '3.0159883720930236%', 'Dataset 2': '15.915697674418606%', 'Dataset 3': '40.116279069767444%', 'Dataset 4': '40.95203488372093%'}
# --------------------------------------------------------------------------------
# Batch 87
# {652: 'Dataset 4', 56: 'Dataset 3', 32: 'Dataset 3', 38: 'Dataset 2', 609: 'Dataset 4', 40: 'Dataset 2', 44: 'Dataset 2', 29: 'Dataset 3', 4: 'Dataset 4', 3: 'Dataset 3', 6: 'Dataset 1', 49: 'Dataset 3', 238: 'Dataset 4', 9: 'Dataset 3', 21: 'Dataset 2'}
# Running counter: {'Dataset 1': 84, 'Dataset 2': 446, 'Dataset 3': 1119, 'Dataset 4': 1135}
# Running percentages: {'Dataset 1': '3.0172413793103448%', 'Dataset 2': '16.020114942528735%', 'Dataset 3': '40.19396551724138%', 'Dataset 4': '40.76867816091954%'}
# ...
# Running percentages: {'Dataset 1': '3.3466084275436794%', 'Dataset 2': '18.78532887975334%', 'Dataset 3': '38.61767728674204%', 'Dataset 4': '39.25038540596095%'}
# --------------------------------------------------------------------------------
# Batch 974
# {888: 'Dataset 4', 39: 'Dataset 3', 89: 'Dataset 3', 30: 'Dataset 3', 19: 'Dataset 2', 40: 'Dataset 3', 5: 'Dataset 1', 857: 'Dataset 4', 848: 'Dataset 4', 428: 'Dataset 4', 16: 'Dataset 2', 27: 'Dataset 3'}
# Running counter: {'Dataset 1': 1043, 'Dataset 2': 5852, 'Dataset 3': 12036, 'Dataset 4': 12237}
# Running percentages: {'Dataset 1': '3.3463809034907595%', 'Dataset 2': '18.775667351129364%', 'Dataset 3': '38.616529774127315%', 'Dataset 4': '39.26142197125257%'}
# --------------------------------------------------------------------------------
# Batch 975
# {77: 'Dataset 3', 75: 'Dataset 3', 521: 'Dataset 4', 356: 'Dataset 4', 9: 'Dataset 3', 573: 'Dataset 4', 44: 'Dataset 3', 8: 'Dataset 1', 789: 'Dataset 4', 32: 'Dataset 3'}
# Running counter: {'Dataset 1': 1044, 'Dataset 2': 5852, 'Dataset 3': 12051, 'Dataset 4': 12253}
# Running percentages: {'Dataset 1': '3.346153846153846%', 'Dataset 2': '18.756410256410255%', 'Dataset 3': '38.625%', 'Dataset 4': '39.2724358974359%'}
# --------------------------------------------------------------------------------
# Batch 976
# {32: 'Dataset 3', 80: 'Dataset 3', 869: 'Dataset 4', 9: 'Dataset 2', 542: 'Dataset 4', 466: 'Dataset 4', 729: 'Dataset 4', 4: 'Dataset 1', 68: 'Dataset 3', 720: 'Dataset 4', 24: 'Dataset 2'}
# Running counter: {'Dataset 1': 1045, 'Dataset 2': 5855, 'Dataset 3': 12060, 'Dataset 4': 12272}
# Running percentages: {'Dataset 1': '3.3459272540983602%', 'Dataset 2': '18.746798155737704%', 'Dataset 3': '38.61424180327869%', 'Dataset 4': '39.29303278688525%'}
# --------------------------------------------------------------------------------
# Batch 977
# {47: 'Dataset 2', 905: 'Dataset 4', 842: 'Dataset 4', 73: 'Dataset 3', 0: 'Dataset 3', 76: 'Dataset 3', 46: 'Dataset 3', 75: 'Dataset 3'}
# Running counter: {'Dataset 1': 1045, 'Dataset 2': 5860, 'Dataset 3': 12081, 'Dataset 4': 12278}
# Running percentages: {'Dataset 1': '3.3425025588536337%', 'Dataset 2': '18.74360286591607%', 'Dataset 3': '38.64188843398158%', 'Dataset 4': '39.272006141248724%'}
# --------------------------------------------------------------------------------
# Batch 978
# {75: 'Dataset 3', 12: 'Dataset 2', 47: 'Dataset 2', 20: 'Dataset 2', 907: 'Dataset 4', 21: 'Dataset 3', 4: 'Dataset 1', 10: 'Dataset 3', 2: 'Dataset 2', 30: 'Dataset 2', 844: 'Dataset 4', 17: 'Dataset 2', 38: 'Dataset 3', 18: 'Dataset 3'}
# Running counter: {'Dataset 1': 1046, 'Dataset 2': 5868, 'Dataset 3': 12096, 'Dataset 4': 12286}
# Running percentages: {'Dataset 1': '3.342280163599182%', 'Dataset 2': '18.75%', 'Dataset 3': '38.65030674846626%', 'Dataset 4': '39.25741308793456%'}
# --------------------------------------------------------------------------------
# Batch 979
# {18: 'Dataset 3', 8: 'Dataset 3', 410: 'Dataset 4', 751: 'Dataset 4', 911: 'Dataset 4', 2: 'Dataset 2', 46: 'Dataset 3', 68: 'Dataset 3', 38: 'Dataset 2', 671: 'Dataset 4', 923: 'Dataset 4', 7: 'Dataset 3', 414: 'Dataset 4'}
# Running counter: {'Dataset 1': 1046, 'Dataset 2': 5872, 'Dataset 3': 12111, 'Dataset 4': 12299}
# Running percentages: {'Dataset 1': '3.3388661899897856%', 'Dataset 2': '18.74361593462717%', 'Dataset 3': '38.65870786516854%', 'Dataset 4': '39.2588100102145%'}
# --------------------------------------------------------------------------------
# Batch 980
# {754: 'Dataset 4', 39: 'Dataset 3', 72: 'Dataset 3', 40: 'Dataset 2', 908: 'Dataset 4', 52: 'Dataset 3', 30: 'Dataset 2', 32: 'Dataset 2', 75: 'Dataset 3', 90: 'Dataset 3', 824: 'Dataset 4', 925: 'Dataset 4'}
# Running counter: {'Dataset 1': 1046, 'Dataset 2': 5882, 'Dataset 3': 12124, 'Dataset 4': 12308}
# Running percentages: {'Dataset 1': '3.335459183673469%', 'Dataset 2': '18.75637755102041%', 'Dataset 3': '38.660714285714285%', 'Dataset 4': '39.24744897959184%'}
# --------------------------------------------------------------------------------
# Batch 981
# {925: 'Dataset 4', 36: 'Dataset 2', 17: 'Dataset 2', 60: 'Dataset 3', 14: 'Dataset 2', 915: 'Dataset 4', 50: 'Dataset 3', 374: 'Dataset 4', 61: 'Dataset 3', 97: 'Dataset 3', 673: 'Dataset 4', 49: 'Dataset 2', 20: 'Dataset 2', 57: 'Dataset 3', 894: 'Dataset 4'}
# Running counter: {'Dataset 1': 1046, 'Dataset 2': 5890, 'Dataset 3': 12138, 'Dataset 4': 12318}
# Running percentages: {'Dataset 1': '3.3320591233435266%', 'Dataset 2': '18.762742099898063%', 'Dataset 3': '38.665902140672785%', 'Dataset 4': '39.239296636085626%'}
# --------------------------------------------------------------------------------
# Batch 982
# {1: 'Dataset 3', 21: 'Dataset 2', 96: 'Dataset 3', 30: 'Dataset 2', 98: 'Dataset 3', 34: 'Dataset 2', 44: 'Dataset 2', 2: 'Dataset 1', 10: 'Dataset 2', 9: 'Dataset 1', 11: 'Dataset 2', 70: 'Dataset 3', 58: 'Dataset 3', 45: 'Dataset 2', 645: 'Dataset 4'}
# Running counter: {'Dataset 1': 1048, 'Dataset 2': 5901, 'Dataset 3': 12155, 'Dataset 4': 12320}
# Running percentages: {'Dataset 1': '3.335030549898167%', 'Dataset 2': '18.778640529531568%', 'Dataset 3': '38.68062627291242%', 'Dataset 4': '39.205702647657844%'}
# --------------------------------------------------------------------------------
# Batch 983
# {645: 'Dataset 4', 172: 'Dataset 4', 34: 'Dataset 2', 45: 'Dataset 3', 42: 'Dataset 3', 919: 'Dataset 4', 841: 'Dataset 4', 18: 'Dataset 2', 25: 'Dataset 3', 17: 'Dataset 2', 61: 'Dataset 3', 823: 'Dataset 4', 40: 'Dataset 2', 4: 'Dataset 3', 28: 'Dataset 2', 721: 'Dataset 4', 1: 'Dataset 2', 67: 'Dataset 3'}
# Running counter: {'Dataset 1': 1048, 'Dataset 2': 5908, 'Dataset 3': 12167, 'Dataset 4': 12333}
# Running percentages: {'Dataset 1': '3.3316378433367246%', 'Dataset 2': '18.78179043743642%', 'Dataset 3': '38.67942522889115%', 'Dataset 4': '39.20714649033571%'}
# --------------------------------------------------------------------------------
# Batch 984
# {67: 'Dataset 3', 51: 'Dataset 3', 855: 'Dataset 4', 76: 'Dataset 3', 1: 'Dataset 1', 902: 'Dataset 4', 774: 'Dataset 4', 22: 'Dataset 3', 55: 'Dataset 3', 19: 'Dataset 2', 39: 'Dataset 2', 815: 'Dataset 4', 90: 'Dataset 3', 858: 'Dataset 4', 53: 'Dataset 3'}
# Running counter: {'Dataset 1': 1049, 'Dataset 2': 5910, 'Dataset 3': 12182, 'Dataset 4': 12347}
# Running percentages: {'Dataset 1': '3.3314278455284554%', 'Dataset 2': '18.76905487804878%', 'Dataset 3': '38.68775406504065%', 'Dataset 4': '39.21176321138211%'}
# --------------------------------------------------------------------------------
# Batch 985
# {53: 'Dataset 3', 48: 'Dataset 3', 78: 'Dataset 3', 30: 'Dataset 2', 834: 'Dataset 4', 16: 'Dataset 2', 922: 'Dataset 4', 28: 'Dataset 2', 36: 'Dataset 2', 46: 'Dataset 2', 76: 'Dataset 3', 47: 'Dataset 2', 647: 'Dataset 4', 8: 'Dataset 1', 83: 'Dataset 3', 85: 'Dataset 3', 843: 'Dataset 4', 42: 'Dataset 2'}
# Running counter: {'Dataset 1': 1050, 'Dataset 2': 5922, 'Dataset 3': 12195, 'Dataset 4': 12353}
# Running percentages: {'Dataset 1': '3.3312182741116754%', 'Dataset 2': '18.788071065989847%', 'Dataset 3': '38.68972081218274%', 'Dataset 4': '39.190989847715734%'}
# --------------------------------------------------------------------------------
# Batch 986
# {90: 'Dataset 3', 806: 'Dataset 4', 872: 'Dataset 4', 15: 'Dataset 2', 458: 'Dataset 4', 710: 'Dataset 4', 88: 'Dataset 3', 924: 'Dataset 4', 960: 'Dataset 4', 99: 'Dataset 3', 290: 'Dataset 4', 79: 'Dataset 3', 13: 'Dataset 2', 5: 'Dataset 1', 11: 'Dataset 2'}
# Running counter: {'Dataset 1': 1051, 'Dataset 2': 5925, 'Dataset 3': 12207, 'Dataset 4': 12369}
# Running percentages: {'Dataset 1': '3.331009127789047%', 'Dataset 2': '18.77852434077079%', 'Dataset 3': '38.68851419878296%', 'Dataset 4': '39.2019523326572%'}
# --------------------------------------------------------------------------------
# Batch 987
# {15: 'Dataset 3', 80: 'Dataset 3', 887: 'Dataset 4', 933: 'Dataset 4', 58: 'Dataset 3', 0: 'Dataset 3', 904: 'Dataset 4', 871: 'Dataset 4', 35: 'Dataset 2', 99: 'Dataset 3', 792: 'Dataset 4', 40: 'Dataset 2', 4: 'Dataset 2', 49: 'Dataset 2', 34: 'Dataset 2', 29: 'Dataset 3', 777: 'Dataset 4'}
# Running counter: {'Dataset 1': 1051, 'Dataset 2': 5932, 'Dataset 3': 12218, 'Dataset 4': 12383}
# Running percentages: {'Dataset 1': '3.3276342451874363%', 'Dataset 2': '18.781661600810537%', 'Dataset 3': '38.68414387031408%', 'Dataset 4': '39.20656028368794%'}
# --------------------------------------------------------------------------------
# Batch 988
# {777: 'Dataset 4', 2: 'Dataset 3', 868: 'Dataset 4', 59: 'Dataset 3', 13: 'Dataset 2', 0: 'Dataset 2', 895: 'Dataset 4', 48: 'Dataset 2', 15: 'Dataset 2', 39: 'Dataset 3', 914: 'Dataset 4', 61: 'Dataset 3', 510: 'Dataset 4', 72: 'Dataset 3'}
# Running counter: {'Dataset 1': 1051, 'Dataset 2': 5936, 'Dataset 3': 12234, 'Dataset 4': 12395}
# Running percentages: {'Dataset 1': '3.324266194331984%', 'Dataset 2': '18.775303643724698%', 'Dataset 3': '38.6955971659919%', 'Dataset 4': '39.20483299595141%'}
# --------------------------------------------------------------------------------
# Batch 989
# {5: 'Dataset 2', 7: 'Dataset 1', 81: 'Dataset 3', 811: 'Dataset 4', 801: 'Dataset 4', 676: 'Dataset 4', 27: 'Dataset 2', 877: 'Dataset 4', 0: 'Dataset 1', 584: 'Dataset 4', 900: 'Dataset 4', 71: 'Dataset 3'}
# Running counter: {'Dataset 1': 1053, 'Dataset 2': 5938, 'Dataset 3': 12244, 'Dataset 4': 12413}
# Running percentages: {'Dataset 1': '3.3272244691607686%', 'Dataset 2': '18.762639029322546%', 'Dataset 3': '38.68806875631952%', 'Dataset 4': '39.22206774519717%'}
# --------------------------------------------------------------------------------
# Batch 990
# {748: 'Dataset 4', 892: 'Dataset 4', 245: 'Dataset 4', 89: 'Dataset 3', 67: 'Dataset 3', 30: 'Dataset 3', 937: 'Dataset 4', 42: 'Dataset 2', 24: 'Dataset 2', 21: 'Dataset 2', 34: 'Dataset 2'}
# Running counter: {'Dataset 1': 1053, 'Dataset 2': 5946, 'Dataset 3': 12255, 'Dataset 4': 12426}
# Running percentages: {'Dataset 1': '3.3238636363636367%', 'Dataset 2': '18.768939393939394%', 'Dataset 3': '38.683712121212125%', 'Dataset 4': '39.223484848484844%'}
# --------------------------------------------------------------------------------
# Batch 991
# {46: 'Dataset 2', 28: 'Dataset 3', 696: 'Dataset 4', 24: 'Dataset 2', 9: 'Dataset 1', 97: 'Dataset 3', 17: 'Dataset 2', 18: 'Dataset 2', 61: 'Dataset 3', 11: 'Dataset 2', 16: 'Dataset 2', 68: 'Dataset 3', 769: 'Dataset 4', 12: 'Dataset 3', 677: 'Dataset 4', 44: 'Dataset 2'}
# Running counter: {'Dataset 1': 1055, 'Dataset 2': 5960, 'Dataset 3': 12268, 'Dataset 4': 12429}
# Running percentages: {'Dataset 1': '3.3268163471241166%', 'Dataset 2': '18.794147325933398%', 'Dataset 3': '38.68567103935418%', 'Dataset 4': '39.19336528758829%'}
# --------------------------------------------------------------------------------
# Batch 992
# {57: 'Dataset 3', 826: 'Dataset 4', 610: 'Dataset 4', 16: 'Dataset 2', 4: 'Dataset 1', 809: 'Dataset 4', 66: 'Dataset 3', 49: 'Dataset 3', 2: 'Dataset 1', 91: 'Dataset 3', 241: 'Dataset 4', 1: 'Dataset 2'}
# Running counter: {'Dataset 1': 1057, 'Dataset 2': 5962, 'Dataset 3': 12281, 'Dataset 4': 12444}
# Running percentages: {'Dataset 1': '3.3297631048387095%', 'Dataset 2': '18.781502016129032%', 'Dataset 3': '38.68762600806452%', 'Dataset 4': '39.201108870967744%'}
# --------------------------------------------------------------------------------
# Batch 993
# {42: 'Dataset 3', 9: 'Dataset 1', 46: 'Dataset 2', 89: 'Dataset 3', 68: 'Dataset 3', 26: 'Dataset 2', 736: 'Dataset 4', 47: 'Dataset 3', 28: 'Dataset 2', 975: 'Dataset 4', 865: 'Dataset 4', 10: 'Dataset 3', 51: 'Dataset 3'}
# Running counter: {'Dataset 1': 1059, 'Dataset 2': 5967, 'Dataset 3': 12299, 'Dataset 4': 12451}
# Running percentages: {'Dataset 1': '3.332703927492447%', 'Dataset 2': '18.77832326283988%', 'Dataset 3': '38.70531218529708%', 'Dataset 4': '39.18366062437059%'}
# --------------------------------------------------------------------------------
# Batch 994
# {94: 'Dataset 3', 3: 'Dataset 2', 32: 'Dataset 3', 733: 'Dataset 4', 63: 'Dataset 3', 6: 'Dataset 1', 623: 'Dataset 4', 33: 'Dataset 3', 37: 'Dataset 2', 41: 'Dataset 3', 91: 'Dataset 3', 810: 'Dataset 4', 39: 'Dataset 3', 9: 'Dataset 2', 19: 'Dataset 2', 44: 'Dataset 2', 906: 'Dataset 4'}
# Running counter: {'Dataset 1': 1060, 'Dataset 2': 5974, 'Dataset 3': 12314, 'Dataset 4': 12460}
# Running percentages: {'Dataset 1': '3.3324949698189137%', 'Dataset 2': '18.781438631790746%', 'Dataset 3': '38.71353118712273%', 'Dataset 4': '39.17253521126761%'}
# --------------------------------------------------------------------------------
# Batch 995
# {837: 'Dataset 4', 2: 'Dataset 1', 976: 'Dataset 4', 5: 'Dataset 2', 71: 'Dataset 3', 13: 'Dataset 2', 40: 'Dataset 3', 981: 'Dataset 4', 973: 'Dataset 4', 618: 'Dataset 4', 971: 'Dataset 4', 954: 'Dataset 4'}
# Running counter: {'Dataset 1': 1061, 'Dataset 2': 5982, 'Dataset 3': 12321, 'Dataset 4': 12476}
# Running percentages: {'Dataset 1': '3.332286432160804%', 'Dataset 2': '18.787688442211056%', 'Dataset 3': '38.696608040201%', 'Dataset 4': '39.18341708542714%'}
# --------------------------------------------------------------------------------
# Batch 996
# {954: 'Dataset 4', 24: 'Dataset 3', 496: 'Dataset 4', 931: 'Dataset 4', 49: 'Dataset 3', 36: 'Dataset 3', 606: 'Dataset 4', 928: 'Dataset 4', 31: 'Dataset 2', 29: 'Dataset 3', 28: 'Dataset 2', 3: 'Dataset 3'}
# Running counter: {'Dataset 1': 1061, 'Dataset 2': 5985, 'Dataset 3': 12337, 'Dataset 4': 12489}
# Running percentages: {'Dataset 1': '3.3289407630522088%', 'Dataset 2': '18.778237951807228%', 'Dataset 3': '38.70795682730924%', 'Dataset 4': '39.184864457831324%'}
# --------------------------------------------------------------------------------
# Batch 997
# {27: 'Dataset 2', 784: 'Dataset 4', 0: 'Dataset 3', 927: 'Dataset 4', 978: 'Dataset 4', 965: 'Dataset 4', 34: 'Dataset 2', 20: 'Dataset 2', 47: 'Dataset 2', 14: 'Dataset 2', 39: 'Dataset 3', 53: 'Dataset 3', 7: 'Dataset 1', 982: 'Dataset 4', 4: 'Dataset 3'}
# Running counter: {'Dataset 1': 1062, 'Dataset 2': 5994, 'Dataset 3': 12345, 'Dataset 4': 12503}
# Running percentages: {'Dataset 1': '3.328736208625878%', 'Dataset 2': '18.787612838515546%', 'Dataset 3': '38.6942076228686%', 'Dataset 4': '39.18944332998997%'}
# --------------------------------------------------------------------------------
# Batch 998
# {4: 'Dataset 3', 18: 'Dataset 2', 559: 'Dataset 4', 67: 'Dataset 3', 99: 'Dataset 3', 82: 'Dataset 3', 20: 'Dataset 3', 41: 'Dataset 3', 88: 'Dataset 3', 838: 'Dataset 4', 812: 'Dataset 4', 829: 'Dataset 4', 600: 'Dataset 4'}
# Running counter: {'Dataset 1': 1062, 'Dataset 2': 5996, 'Dataset 3': 12362, 'Dataset 4': 12516}
# Running percentages: {'Dataset 1': '3.3254008016032066%', 'Dataset 2': '18.7750501002004%', 'Dataset 3': '38.708667334669336%', 'Dataset 4': '39.19088176352705%'}
# --------------------------------------------------------------------------------
# Batch 999
# {600: 'Dataset 4', 949: 'Dataset 4', 74: 'Dataset 3', 46: 'Dataset 2', 79: 'Dataset 3', 28: 'Dataset 3', 977: 'Dataset 4', 54: 'Dataset 3', 21: 'Dataset 3', 86: 'Dataset 3', 13: 'Dataset 3'}
# Running counter: {'Dataset 1': 1062, 'Dataset 2': 5997, 'Dataset 3': 12383, 'Dataset 4': 12526}
# Running percentages: {'Dataset 1': '3.3220720720720722%', 'Dataset 2': '18.759384384384383%', 'Dataset 3': '38.73561061061061%', 'Dataset 4': '39.182932932932935%'}
# --------------------------------------------------------------------------------
# Batch 1000
# {13: 'Dataset 3', 82: 'Dataset 3', 98: 'Dataset 3', 1: 'Dataset 1', 20: 'Dataset 3', 852: 'Dataset 4', 958: 'Dataset 4', 782: 'Dataset 4', 5: 'Dataset 1', 39: 'Dataset 2', 40: 'Dataset 3', 24: 'Dataset 3', 963: 'Dataset 4'}
# Running counter: {'Dataset 1': 1064, 'Dataset 2': 5999, 'Dataset 3': 12398, 'Dataset 4': 12539}
# Running percentages: {'Dataset 1': '3.325%', 'Dataset 2': '18.746875%', 'Dataset 3': '38.74375%', 'Dataset 4': '39.184374999999996%'}
# --------------------------------------------------------------------------------
